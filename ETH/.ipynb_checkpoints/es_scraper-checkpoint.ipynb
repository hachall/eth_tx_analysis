# %% [markdown]
# ## Collecting labelled addresses for ETH

# %% [markdown]
# Fetches and labels ethereum addresses from Etherscan.com.

# %%
import bs4
import requests
import csv
import time
import math

# %%
def append_list_as_row(file_name, list_of_elem):
    # Open file in append mode
    with open(file_name, 'a+', newline='') as write_obj:
        # Create a writer object from csv module
        csv_writer = csv.writer(write_obj)
        # Add contents of list as last row in the csv file
        csv_writer.writerow(list_of_elem)

def write_list_as_row(file_name, list_of_elem):
    # Truncates file to empty then writes row
    with open(file_name, 'w+', newline='') as write_obj:
        # Create a writer object from csv module
        csv_writer = csv.writer(write_obj)
        # Add contents of list as last row in the csv file
        csv_writer.writerow(list_of_elem)

# %%
#generate urls
def generate_urls(prefix, suffix, r):
    if r == 0:
        return [prefix]
    
    urls = []
    for x in range(0, r):
        urls.append(prefix + str(x + 1) + suffix)

    return urls

# %%
def get_page(url, headers):
    resp = requests.get(url, headers=headers, timeout=None)
    soup = bs4.BeautifulSoup(resp.text, 'html5lib')
#     print(soup.prettify())
    return soup

# %%
def get_rows(page):
    if page.tbody:
        return page.tbody.find_all('tr')
    else:
        return []

# %%
def trim_rows(data, start, finish):
    return data[start:finish]

# %%
def save_data_to_csv(file, data):  
    for item in data:
        cols = item.find_all('td')
        row = []
        for col in cols:
            row.append(col.text)
        
        append_list_as_row(file, row)

# %%
headers = {
    'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) snap Chromium/83.0.4103.97 Chrome/83.0.4103.97 Safari/537.36",
    'cookie': "__cfduid=d45fca5c2d9141aff89f4de19316344d21591611382; ASP.NET_SessionId=1aqgu2qpziantjigxlwtb4ay; _ga=GA1.2.811314642.1591611384; _gid=GA1.2.735645790.1591871016; _gat_gtag_UA_46998878_6=1"
}

# %%
def address_scraper(file, prefix, suffix, r, headers, urls=None):
    
    if not urls:   
        urls = generate_urls(prefix, suffix, r)

    for url in urls:
        print(f"Fetching {url}")
        page = get_page(url, headers)
        data = get_rows(page)
        save_data_to_csv(file, data)
        print("page written to file.")
        time.sleep(5)

    print("finished.")

# %%
# #Exchanges
# ex_file = "exchanges.csv"
# ex_base = "https://etherscan.io/accounts/label/exchange/"
# ex_end = "?ps=100"
# pages = 3
# address_scraper(ex_file, ex_base, ex_end, pages, headers)

# %%
# #Exchange tokens
# ext_file = "exchanges_tokens.csv"
# ext_base = "https://etherscan.io/tokens/label/exchange?ps=100&p="
# ext_end = ""
# pages = 2
# address_scraper(ext_file, ext_base, ext_end, pages, headers)

# %%
# #DEXs
# dex_file = "dex.csv"
# dex_base = "https://etherscan.io/accounts/label/dex?ps=100"

# address_scraper(dex_file, dex_base, "", 0, headers)

# %%
# #DEX Tokens
# dext_file = "dex_tokens.csv"
# dext_base = "https://etherscan.io/tokens/label/dex"
# address_scraper(dext_file, dext_base, "", 0, headers)

# %%
# #ICO Wallets
# icow_file = "ico_wallets.csv"

# icow_base = "https://etherscan.io/accounts/label/ico-wallets/"
# icow_end = "?ps=100"
# pages = 2
# address_scraper(icow_file, icow_base, icow_end, pages, headers)

# %%
# #Miners
# m_file = "miners.csv"

# m_base = "https://etherscan.io/accounts/label/mining?ps=100"

# address_scraper(m_file, m_base, "", 0, headers)

# %%
# #Miners Tokens
# mt_file = "miners_tokens.csv"
# mt_base = "https://etherscan.io/tokens/label/mining?ps=100"

# address_scraper(mt_file, mt_base, "", 0, headers)

# %%
# #Tokens
# t_file = "tokens.csv"
# t_base = "https://etherscan.io/accounts/label/token-contract/"
# t_end = "?ps=100"
# pages = 27
# address_scraper(t_file, t_base, t_end, pages, headers)

# %%
def str_parser(i):
    s = i.split(" ")
    word = s[0].lower()
    num = int(s[1][1:-1])
    return word, num

# %%
def scrape_categories(headers):
    s = get_page("https://etherscan.io/labelcloud", headers)
    x = s.find_all('div', class_='secondary-container')
    
    categories = []

    for i in x:
        sub_c = {}
        sub_c['name'] = i.find('div', class_="dropdown-menu")['aria-labelledby']
        sub_c['url'] = i.button['data-url']

        
        for index in range(0, len(i.find_all('a'))):
            text = i.find_all('a')[index].text
            word, num = str_parser(text)
            if word != 'transactions':
                sub_c[word] = num

#         first = i.find_all('a')[0].text
#         word, num = str_parser(first)
#         if word != 'transactions':
#             sub_c[word] = num
        
        
#         if len(i.find_all('a')) > 1:
#             second = i.find_all('a')[1].text 
#             word2, num2 = 
#             if second[0:2] != 'Tr':   
#                 sub_c[indexes[index*-1]] = str_parser(second)

        categories.append(sub_c)
        
    return categories

# %%
def split_categories(c):
    legit = []
    scams_and_hacks = []

    illegitimate_kw = ['hack', 'phish', 'scam', 'compromised', 'ponzi', 'exploit', 'trapped', 'down', 'unstoppable', 'suspicious', 'unsafe', 'spam']

    for item in c:
        for word in illegitimate_kw:
            if word in item['name'].lower().split(" "):
                scams_and_hacks.append(item)
                break
        else:
            legit.append(item)

    return legit, scams_and_hacks

# %%
def make_urls(typ, item):
    base = "https://etherscan.io/" + typ + "/label/" + item['url']
    urls = []
    
    if item[typ] < 100:
        base += "?ps=100"
        urls.append(base)
        
    else:
        urls = []
        pages = math.ceil(item[typ]/100)
        
        for i in range(0, pages):
            urls.append(base + '/' + str(i+1) + "?ps=100")
        
    return urls

# %%
def data_generator(l):
    data = []

    for item in l:

        for key in item.keys():    
            if key == 'name' or key == 'url':
                continue
            data_item = [item['name'], key]
            data_item.append(make_urls(key, item))

            data.append(data_item)
            
    return data

# %%
def mega_scraper(file, headers, d):
    for category in d:
        print(f"Fetching {category[0]} {category[1]}")
        for url in category[2]:
            print(f"Fetching {url}")
            page = get_page(url, headers)
            data = get_rows(page)
            save_data_to_csv2(file, data, category[1], category[0])
            print("page written to file.")
            time.sleep(5)

    print("finished.")

# %%
def save_data_to_csv2(file, data, typ, cat):  
    for item in data:
        if (len(item) <= 2):
            continue #No entries in table
            
        cols = item.find_all('td')
        
        row = []
        if typ == 'accounts': 
            row.append(cols[0].text)
            row.append(cols[1].text)
            row.append(typ)
            row.append(cat)
            row.append(cols[2].text)
            row.append(cols[3].text)
        else:
            row.append(cols[1].text)
            row.append(cols[2].text)
            row.append(typ)
            row.append(cat)
            row.append(cols[3].text)
            row.append(cols[4].text)
        
        append_list_as_row(file, row)

# %%
#set up files
legit_csv = "legit.csv"
write_list_as_row(legit_csv, [])
dodgy_csv = "dodgy.csv"
write_list_as_row(dodgy_csv, [])

# %%
c = scrape_categories(headers)
l, s = split_categories(c)

# %%
#For each category generate a list: [Category, type [account/token], urls]
data_legit = data_generator(l)
data_illegit = data_generator(s)
print(data_legit)
# Out:
# [['0x', 'accounts', ['https://etherscan.io/accounts/label/0x?ps=100']], ['0x', 'tokens', ['https://etherscan.io/tokens/label/0x?ps=100']], ['0x Ecosystem', 'accounts', ['https://etherscan.io/accounts/label/0x-ecosystem?ps=100']], ['0x Ecosystem', 'tokens', ['https://etherscan.io/tokens/label/0x-ecosystem?ps=100']], ['0xUniverse', 'accounts', ['https://etherscan.io/accounts/label/0xuniverse?ps=100']], ['0xUniverse', 'tokens', ['https://etherscan.io/tokens/label/0xuniverse?ps=100']], ['Aave', 'accounts', ['https://etherscan.io/accounts/label/aave?ps=100']], ['Aave', 'tokens', ['https://etherscan.io/tokens/label/aave?ps=100']], ['ABCC', 'accounts', ['https://etherscan.io/accounts/label/abcc?ps=100']], ['ABCC', 'tokens', ['https://etherscan.io/tokens/label/abcc?ps=100']], ['Adult', 'tokens', ['https://etherscan.io/tokens/label/adult?ps=100']], ['Advertising', 'accounts', ['https://etherscan.io/accounts/label/advertising?ps=100']], ['Advertising', 'tokens', ['https://etherscan.io/tokens/label/advertising?ps=100']], ['Agriculture', 'tokens', ['https://etherscan.io/tokens/label/agriculture?ps=100']], ['Airdrop / Distributor', 'accounts', ['https://etherscan.io/accounts/label/airdrop-distributor?ps=100']], ['Airdrop / Distributor', 'tokens', ['https://etherscan.io/tokens/label/airdrop-distributor?ps=100']], ['AirSwap', 'accounts', ['https://etherscan.io/accounts/label/airswap?ps=100']], ['AirSwap', 'tokens', ['https://etherscan.io/tokens/label/airswap?ps=100']], ['Allbit', 'accounts', ['https://etherscan.io/accounts/label/allbit?ps=100']], ['Ampleforth ', 'accounts', ['https://etherscan.io/accounts/label/ampleforth?ps=100']], ['Ampleforth ', 'tokens', ['https://etherscan.io/tokens/label/ampleforth?ps=100']], ['Analytics', 'tokens', ['https://etherscan.io/tokens/label/analytics?ps=100']], ['App Development', 'tokens', ['https://etherscan.io/tokens/label/app-development?ps=100']], ['Apparel', 'tokens', ['https://etherscan.io/tokens/label/apparel?ps=100']], ['AR', 'tokens', ['https://etherscan.io/tokens/label/ar?ps=100']], ['Art', 'tokens', ['https://etherscan.io/tokens/label/art?ps=100']], ['Artificial Intelligence', 'tokens', ['https://etherscan.io/tokens/label/artificial-intelligence?ps=100']], ['Artworks', 'tokens', ['https://etherscan.io/tokens/label/artworks?ps=100']], ['Asset Management', 'tokens', ['https://etherscan.io/tokens/label/asset-management?ps=100']], ['Asset Token', 'tokens', ['https://etherscan.io/tokens/label/asset-token?ps=100']], ['AtomSolutions', 'accounts', ['https://etherscan.io/accounts/label/atomsolutions?ps=100']], ['AtomSolutions', 'tokens', ['https://etherscan.io/tokens/label/atomsolutions?ps=100']], ['Auction', 'accounts', ['https://etherscan.io/accounts/label/auction?ps=100']], ['Authentication', 'tokens', ['https://etherscan.io/tokens/label/authentication?ps=100']], ['Authereum', 'accounts', ['https://etherscan.io/accounts/label/authereum?ps=100']], ['Aviation ', 'tokens', ['https://etherscan.io/tokens/label/aviation?ps=100']], ['Bancor', 'accounts', ['https://etherscan.io/accounts/label/bancor/1?ps=100', 'https://etherscan.io/accounts/label/bancor/2?ps=100', 'https://etherscan.io/accounts/label/bancor/3?ps=100']], ['Bancor', 'tokens', ['https://etherscan.io/tokens/label/bancor?ps=100']], ['Band', 'accounts', ['https://etherscan.io/accounts/label/band?ps=100']], ['Band', 'tokens', ['https://etherscan.io/tokens/label/band?ps=100']], ['Banking', 'tokens', ['https://etherscan.io/tokens/label/banking?ps=100']], ['Basic Attention Token', 'accounts', ['https://etherscan.io/accounts/label/basic-attention-token?ps=100']], ['Basic Attention Token', 'tokens', ['https://etherscan.io/tokens/label/basic-attention-token?ps=100']], ['Beauty', 'tokens', ['https://etherscan.io/tokens/label/beauty?ps=100']], ['Bgogo', 'accounts', ['https://etherscan.io/accounts/label/bgogo?ps=100']], ['Bgogo', 'tokens', ['https://etherscan.io/tokens/label/bgogo?ps=100']], ['Binance', 'accounts', ['https://etherscan.io/accounts/label/binanc ...

# %%
# mega_scraper(dodgy_csv, headers, data_illegit)
mega_scraper(legit_csv, headers, data_legit)
# Out:
# Fetching 0x accounts
# Fetching https://etherscan.io/accounts/label/0x?ps=100
# page written to file.
# Fetching 0x tokens
# Fetching https://etherscan.io/tokens/label/0x?ps=100
# page written to file.
# Fetching 0x Ecosystem accounts
# Fetching https://etherscan.io/accounts/label/0x-ecosystem?ps=100
# page written to file.
# Fetching 0x Ecosystem tokens
# Fetching https://etherscan.io/tokens/label/0x-ecosystem?ps=100
# page written to file.
# Fetching 0xUniverse accounts
# Fetching https://etherscan.io/accounts/label/0xuniverse?ps=100
# page written to file.
# Fetching 0xUniverse tokens
# Fetching https://etherscan.io/tokens/label/0xuniverse?ps=100
# page written to file.
# Fetching Aave accounts
# Fetching https://etherscan.io/accounts/label/aave?ps=100
# page written to file.
# Fetching Aave tokens
# Fetching https://etherscan.io/tokens/label/aave?ps=100
# page written to file.
# Fetching ABCC accounts
# Fetching https://etherscan.io/accounts/label/abcc?ps=100
# page written to file.
# Fetching ABCC tokens
# Fetching https://etherscan.io/tokens/label/abcc?ps=100
# page written to file.
# Fetching Adult tokens
# Fetching https://etherscan.io/tokens/label/adult?ps=100
# page written to file.
# Fetching Advertising accounts
# Fetching https://etherscan.io/accounts/label/advertising?ps=100
# page written to file.
# Fetching Advertising tokens
# Fetching https://etherscan.io/tokens/label/advertising?ps=100
# page written to file.
# Fetching Agriculture tokens
# Fetching https://etherscan.io/tokens/label/agriculture?ps=100
# page written to file.
# Fetching Airdrop / Distributor accounts
# Fetching https://etherscan.io/accounts/label/airdrop-distributor?ps=100
# page written to file.
# Fetching Airdrop / Distributor tokens
# Fetching https://etherscan.io/tokens/label/airdrop-distributor?ps=100
# page written to file.
# Fetching AirSwap accounts
# Fetching https://etherscan.io/accounts/label/airswap?ps=100
# page written to file.
# Fetching AirSwap tokens
# Fetching https://etherscan.io/tokens/label/airswap?ps=100
# page written to file.
# Fetching Allbit accounts
# Fetching https://etherscan.io/accounts/label/allbit?ps=100
# page written to file.
# Fetching Ampleforth  accounts
# Fetching https://etherscan.io/accounts/label/ampleforth?ps=100
# page written to file.
# Fetching Ampleforth  tokens
# Fetching https://etherscan.io/tokens/label/ampleforth?ps=100
# page written to file.
# Fetching Analytics tokens
# Fetching https://etherscan.io/tokens/label/analytics?ps=100
# page written to file.
# Fetching App Development tokens
# Fetching https://etherscan.io/tokens/label/app-development?ps=100
# page written to file.
# Fetching Apparel tokens
# Fetching https://etherscan.io/tokens/label/apparel?ps=100
# page written to file.
# Fetching AR tokens
# Fetching https://etherscan.io/tokens/label/ar?ps=100
# page written to file.
# Fetching Art tokens
# Fetching https://etherscan.io/tokens/label/art?ps=100
# page written to file.
# Fetching Artificial Intelligence tokens
# Fetching https://etherscan.io/tokens/label/artificial-intelligence?ps=100
# page written to file.
# Fetching Artworks tokens
# Fetching https://etherscan.io/tokens/label/artworks?ps=100
# page written to file.
# Fetching Asset Management tokens
# Fetching https://etherscan.io/tokens/label/asset-management?ps=100
# page written to file.
# Fetching Asset Token tokens
# Fetching https://etherscan.io/tokens/label/asset-token?ps=100
# page written to file.
# Fetching AtomSolutions accounts
# Fetching https://etherscan.io/accounts/label/atomsolutions?ps=100
# page written to file.
# Fetching AtomSolutions tokens
# Fetching https://etherscan.io/tokens/label/atomsolutions?ps=100
# page written to file.
# Fetching Auction accounts
# Fetching https://etherscan.io/accounts/label/auction?ps=100
# page written to file.
# Fetching Authentication tokens
# Fetching https://etherscan.io/tokens/label/authentication?ps=100
# page written to file.
# Fetching Authereum accounts
# Fetching https://etherscan.io/accounts/label/authereum?ps=100
# page written to file.
# Fetching Aviation  tokens
# Fetching https://etherscan.io/tokens/label/aviation?ps=100
# page written to file.
# Fetching Bancor accounts
# Fetching https://etherscan.io/accounts/label/bancor/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/bancor/2?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/bancor/3?ps=100
# page written to file.
# Fetching Bancor tokens
# Fetching https://etherscan.io/tokens/label/bancor?ps=100
# page written to file.
# Fetching Band accounts
# Fetching https://etherscan.io/accounts/label/band?ps=100
# page written to file.
# Fetching Band tokens
# Fetching https://etherscan.io/tokens/label/band?ps=100
# page written to file.
# Fetching Banking tokens
# Fetching https://etherscan.io/tokens/label/banking?ps=100
# page written to file.
# Fetching Basic Attention Token accounts
# Fetching https://etherscan.io/accounts/label/basic-attention-token?ps=100
# page written to file.
# Fetching Basic Attention Token tokens
# Fetching https://etherscan.io/tokens/label/basic-attention-token?ps=100
# page written to file.
# Fetching Beauty tokens
# Fetching https://etherscan.io/tokens/label/beauty?ps=100
# page written to file.
# Fetching Bgogo accounts
# Fetching https://etherscan.io/accounts/label/bgogo?ps=100
# page written to file.
# Fetching Bgogo tokens
# Fetching https://etherscan.io/tokens/label/bgogo?ps=100
# page written to file.
# Fetching Binance accounts
# Fetching https://etherscan.io/accounts/label/binance?ps=100
# page written to file.
# Fetching Binance tokens
# Fetching https://etherscan.io/tokens/label/binance?ps=100
# page written to file.
# Fetching Bitcoin Pegged tokens
# Fetching https://etherscan.io/tokens/label/bitcoin-pegged?ps=100
# page written to file.
# Fetching BitcoinSoV accounts
# Fetching https://etherscan.io/accounts/label/bitcoinsov?ps=100
# page written to file.
# Fetching BitcoinSoV tokens
# Fetching https://etherscan.io/tokens/label/bitcoinsov?ps=100
# page written to file.
# Fetching Bitfinex accounts
# Fetching https://etherscan.io/accounts/label/bitfinex?ps=100
# page written to file.
# Fetching Bitfinex tokens
# Fetching https://etherscan.io/tokens/label/bitfinex?ps=100
# page written to file.
# Fetching Bithumb accounts
# Fetching https://etherscan.io/accounts/label/bithumb?ps=100
# page written to file.
# Fetching BitMart accounts
# Fetching https://etherscan.io/accounts/label/bitmart?ps=100
# page written to file.
# Fetching BitMart tokens
# Fetching https://etherscan.io/tokens/label/bitmart?ps=100
# page written to file.
# Fetching BitMax.io accounts
# Fetching https://etherscan.io/accounts/label/bitmax-io?ps=100
# page written to file.
# Fetching BitMax.io tokens
# Fetching https://etherscan.io/tokens/label/bitmax-io?ps=100
# page written to file.
# Fetching Bitpie accounts
# Fetching https://etherscan.io/accounts/label/bitpie?ps=100
# page written to file.
# Fetching Bitstamp accounts
# Fetching https://etherscan.io/accounts/label/bitstamp?ps=100
# page written to file.
# Fetching Bittrex accounts
# Fetching https://etherscan.io/accounts/label/bittrex?ps=100
# page written to file.
# Fetching Blockchain tokens
# Fetching https://etherscan.io/tokens/label/blockchain?ps=100
# page written to file.
# Fetching Blockchain Cuties accounts
# Fetching https://etherscan.io/accounts/label/blockchain-cuties?ps=100
# page written to file.
# Fetching Blockchain Cuties tokens
# Fetching https://etherscan.io/tokens/label/blockchain-cuties?ps=100
# page written to file.
# Fetching Blockchain Phone tokens
# Fetching https://etherscan.io/tokens/label/blockchain-phone?ps=100
# page written to file.
# Fetching Bloom accounts
# Fetching https://etherscan.io/accounts/label/bloom?ps=100
# page written to file.
# Fetching Bloom tokens
# Fetching https://etherscan.io/tokens/label/bloom?ps=100
# page written to file.
# Fetching Bounties accounts
# Fetching https://etherscan.io/accounts/label/bounties?ps=100
# page written to file.
# Fetching Bounties tokens
# Fetching https://etherscan.io/tokens/label/bounties?ps=100
# page written to file.
# Fetching Bounties Network accounts
# Fetching https://etherscan.io/accounts/label/bounties-network?ps=100
# page written to file.
# Fetching Brave Frontier Heroes accounts
# Fetching https://etherscan.io/accounts/label/brave-frontier-heroes?ps=100
# page written to file.
# Fetching Brave Frontier Heroes tokens
# Fetching https://etherscan.io/tokens/label/brave-frontier-heroes?ps=100
# page written to file.
# Fetching Bridge accounts
# Fetching https://etherscan.io/accounts/label/bridge?ps=100
# page written to file.
# Fetching Bugs accounts
# Fetching https://etherscan.io/accounts/label/bugs?ps=100
# page written to file.
# Fetching bZx accounts
# Fetching https://etherscan.io/accounts/label/bzx?ps=100
# page written to file.
# Fetching bZx tokens
# Fetching https://etherscan.io/tokens/label/bzx?ps=100
# page written to file.
# Fetching CACHE Gold accounts
# Fetching https://etherscan.io/accounts/label/cache-gold?ps=100
# page written to file.
# Fetching CACHE Gold tokens
# Fetching https://etherscan.io/tokens/label/cache-gold?ps=100
# page written to file.
# Fetching Celsius Network accounts
# Fetching https://etherscan.io/accounts/label/celsius-network?ps=100
# page written to file.
# Fetching Celsius Network tokens
# Fetching https://etherscan.io/tokens/label/celsius-network?ps=100
# page written to file.
# Fetching Chainlink accounts
# Fetching https://etherscan.io/accounts/label/chainlink?ps=100
# page written to file.
# Fetching Charity accounts
# Fetching https://etherscan.io/accounts/label/charity?ps=100
# page written to file.
# Fetching Charity tokens
# Fetching https://etherscan.io/tokens/label/charity?ps=100
# page written to file.
# Fetching Cheese Wizard accounts
# Fetching https://etherscan.io/accounts/label/cheese-wizard?ps=100
# page written to file.
# Fetching Chibi Fighters accounts
# Fetching https://etherscan.io/accounts/label/chibi-fighters?ps=100
# page written to file.
# Fetching Chibi Fighters tokens
# Fetching https://etherscan.io/tokens/label/chibi-fighters?ps=100
# page written to file.
# Fetching Closure  accounts
# Fetching https://etherscan.io/accounts/label/closure?ps=100
# page written to file.
# Fetching Closure  tokens
# Fetching https://etherscan.io/tokens/label/closure?ps=100
# page written to file.
# Fetching Cloud tokens
# Fetching https://etherscan.io/tokens/label/cloud?ps=100
# page written to file.
# Fetching Cobinhood accounts
# Fetching https://etherscan.io/accounts/label/cobinhood?ps=100
# page written to file.
# Fetching Cobinhood tokens
# Fetching https://etherscan.io/tokens/label/cobinhood?ps=100
# page written to file.
# Fetching Coinbit accounts
# Fetching https://etherscan.io/accounts/label/coinbit?ps=100
# page written to file.
# Fetching Coinbit tokens
# Fetching https://etherscan.io/tokens/label/coinbit?ps=100
# page written to file.
# Fetching Coinhako accounts
# Fetching https://etherscan.io/accounts/label/coinhako?ps=100
# page written to file.
# Fetching CoinMarketFeed accounts
# Fetching https://etherscan.io/accounts/label/coinmarketfeed?ps=100
# page written to file.
# Fetching CoinMarketFeed tokens
# Fetching https://etherscan.io/tokens/label/coinmarketfeed?ps=100
# page written to file.
# Fetching CoinMetro accounts
# Fetching https://etherscan.io/accounts/label/coinmetro?ps=100
# page written to file.
# Fetching CoinMetro tokens
# Fetching https://etherscan.io/tokens/label/coinmetro?ps=100
# page written to file.
# Fetching Coinone accounts
# Fetching https://etherscan.io/accounts/label/coinone?ps=100
# page written to file.
# Fetching Cold Wallet accounts
# Fetching https://etherscan.io/accounts/label/cold-wallet?ps=100
# page written to file.
# Fetching Collaboration tokens
# Fetching https://etherscan.io/tokens/label/collaboration?ps=100
# page written to file.
# Fetching Collectibles accounts
# Fetching https://etherscan.io/accounts/label/collectibles?ps=100
# page written to file.
# Fetching Collectibles tokens
# Fetching https://etherscan.io/tokens/label/collectibles?ps=100
# page written to file.
# Fetching Commodity tokens
# Fetching https://etherscan.io/tokens/label/commodity?ps=100
# page written to file.
# Fetching Communication accounts
# Fetching https://etherscan.io/accounts/label/communication?ps=100
# page written to file.
# Fetching Communication tokens
# Fetching https://etherscan.io/tokens/label/communication?ps=100
# page written to file.
# Fetching Compliance tokens
# Fetching https://etherscan.io/tokens/label/compliance?ps=100
# page written to file.
# Fetching Compound accounts
# Fetching https://etherscan.io/accounts/label/compound?ps=100
# page written to file.
# Fetching Compound tokens
# Fetching https://etherscan.io/tokens/label/compound?ps=100
# page written to file.
# Fetching Computing tokens
# Fetching https://etherscan.io/tokens/label/computing?ps=100
# page written to file.
# Fetching Contract Deployer accounts
# Fetching https://etherscan.io/accounts/label/contract-deployer/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/contract-deployer/2?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/contract-deployer/3?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/contract-deployer/4?ps=100
# page written to file.
# Fetching COSS.io accounts
# Fetching https://etherscan.io/accounts/label/coss-io?ps=100
# page written to file.
# Fetching COSS.io tokens
# Fetching https://etherscan.io/tokens/label/coss-io?ps=100
# page written to file.
# Fetching Counter.Market accounts
# Fetching https://etherscan.io/accounts/label/counter-market?ps=100
# page written to file.
# Fetching CREX24 accounts
# Fetching https://etherscan.io/accounts/label/crex24?ps=100
# page written to file.
# Fetching Crowdfunding tokens
# Fetching https://etherscan.io/tokens/label/crowdfunding?ps=100
# page written to file.
# Fetching Crypto Card tokens
# Fetching https://etherscan.io/tokens/label/crypto-card?ps=100
# page written to file.
# Fetching CryptoAtoms accounts
# Fetching https://etherscan.io/accounts/label/cryptoatoms?ps=100
# page written to file.
# Fetching CryptoAtoms tokens
# Fetching https://etherscan.io/tokens/label/cryptoatoms?ps=100
# page written to file.
# Fetching CryptoBots accounts
# Fetching https://etherscan.io/accounts/label/cryptobots?ps=100
# page written to file.
# Fetching CryptoBots tokens
# Fetching https://etherscan.io/tokens/label/cryptobots?ps=100
# page written to file.
# Fetching CryptoDozer accounts
# Fetching https://etherscan.io/accounts/label/cryptodozer?ps=100
# page written to file.
# Fetching CryptoDozer tokens
# Fetching https://etherscan.io/tokens/label/cryptodozer?ps=100
# page written to file.
# Fetching CryptoKitties accounts
# Fetching https://etherscan.io/accounts/label/cryptokitties?ps=100
# page written to file.
# Fetching CryptoKitties tokens
# Fetching https://etherscan.io/tokens/label/cryptokitties?ps=100
# page written to file.
# Fetching CryptoRome accounts
# Fetching https://etherscan.io/accounts/label/cryptorome?ps=100
# page written to file.
# Fetching CryptoRome tokens
# Fetching https://etherscan.io/tokens/label/cryptorome?ps=100
# page written to file.
# Fetching CryptoSaga accounts
# Fetching https://etherscan.io/accounts/label/cryptosaga?ps=100
# page written to file.
# Fetching CryptoSaga tokens
# Fetching https://etherscan.io/tokens/label/cryptosaga?ps=100
# page written to file.
# Fetching CryptoServal accounts
# Fetching https://etherscan.io/accounts/label/cryptoserval?ps=100
# page written to file.
# Fetching CryptoServal tokens
# Fetching https://etherscan.io/tokens/label/cryptoserval?ps=100
# page written to file.
# Fetching CryptoSpells  accounts
# Fetching https://etherscan.io/accounts/label/cryptospells?ps=100
# page written to file.
# Fetching CryptoSpells  tokens
# Fetching https://etherscan.io/tokens/label/cryptospells?ps=100
# page written to file.
# Fetching CryptoWars accounts
# Fetching https://etherscan.io/accounts/label/cryptowars?ps=100
# page written to file.
# Fetching CryptoWars tokens
# Fetching https://etherscan.io/tokens/label/cryptowars?ps=100
# page written to file.
# Fetching Currency tokens
# Fetching https://etherscan.io/tokens/label/currency?ps=100
# page written to file.
# Fetching Curve.fi accounts
# Fetching https://etherscan.io/accounts/label/curve-fi?ps=100
# page written to file.
# Fetching Curve.fi tokens
# Fetching https://etherscan.io/tokens/label/curve-fi?ps=100
# page written to file.
# Fetching DAO accounts
# Fetching https://etherscan.io/accounts/label/dao?ps=100
# page written to file.
# Fetching DAO tokens
# Fetching https://etherscan.io/tokens/label/dao?ps=100
# page written to file.
# Fetching Darwinia Network accounts
# Fetching https://etherscan.io/accounts/label/darwinia-network?ps=100
# page written to file.
# Fetching Darwinia Network tokens
# Fetching https://etherscan.io/tokens/label/darwinia-network?ps=100
# page written to file.
# Fetching Data tokens
# Fetching https://etherscan.io/tokens/label/data?ps=100
# page written to file.
# Fetching Dating tokens
# Fetching https://etherscan.io/tokens/label/dating?ps=100
# page written to file.
# Fetching Decentraland accounts
# Fetching https://etherscan.io/accounts/label/decentraland?ps=100
# page written to file.
# Fetching Decentraland tokens
# Fetching https://etherscan.io/tokens/label/decentraland?ps=100
# page written to file.
# Fetching DeFi accounts
# Fetching https://etherscan.io/accounts/label/defi?ps=100
# page written to file.
# Fetching DeFi tokens
# Fetching https://etherscan.io/tokens/label/defi?ps=100
# page written to file.
# Fetching DeFi Saver accounts
# Fetching https://etherscan.io/accounts/label/defi-saver?ps=100
# page written to file.
# Fetching Deflationary Token tokens
# Fetching https://etherscan.io/tokens/label/deflationary-token?ps=100
# page written to file.
# Fetching Deprecated accounts
# Fetching https://etherscan.io/accounts/label/deprecated?ps=100
# page written to file.
# Fetching Deprecated tokens
# Fetching https://etherscan.io/tokens/label/deprecated?ps=100
# page written to file.
# Fetching Derivatives accounts
# Fetching https://etherscan.io/accounts/label/derivatives?ps=100
# page written to file.
# Fetching Derivatives tokens
# Fetching https://etherscan.io/tokens/label/derivatives?ps=100
# page written to file.
# Fetching Design tokens
# Fetching https://etherscan.io/tokens/label/design?ps=100
# page written to file.
# Fetching DeversiFi accounts
# Fetching https://etherscan.io/accounts/label/deversifi?ps=100
# page written to file.
# Fetching DeversiFi tokens
# Fetching https://etherscan.io/tokens/label/deversifi?ps=100
# page written to file.
# Fetching Dex accounts
# Fetching https://etherscan.io/accounts/label/dex?ps=100
# page written to file.
# Fetching Dex tokens
# Fetching https://etherscan.io/tokens/label/dex?ps=100
# page written to file.
# Fetching DEX.AG accounts
# Fetching https://etherscan.io/accounts/label/dex-ag?ps=100
# page written to file.
# Fetching dForce accounts
# Fetching https://etherscan.io/accounts/label/dforce?ps=100
# page written to file.
# Fetching dForce tokens
# Fetching https://etherscan.io/tokens/label/dforce?ps=100
# page written to file.
# Fetching Diamonds tokens
# Fetching https://etherscan.io/tokens/label/diamonds?ps=100
# page written to file.
# Fetching DigiFinex accounts
# Fetching https://etherscan.io/accounts/label/digifinex?ps=100
# page written to file.
# Fetching DigiFinex tokens
# Fetching https://etherscan.io/tokens/label/digifinex?ps=100
# page written to file.
# Fetching DINNGO accounts
# Fetching https://etherscan.io/accounts/label/dinngo?ps=100
# page written to file.
# Fetching DINNGO tokens
# Fetching https://etherscan.io/tokens/label/dinngo?ps=100
# page written to file.
# Fetching Donate accounts
# Fetching https://etherscan.io/accounts/label/donate?ps=100
# page written to file.
# Fetching Donate tokens
# Fetching https://etherscan.io/tokens/label/donate?ps=100
# page written to file.
# Fetching Dragonereum accounts
# Fetching https://etherscan.io/accounts/label/dragonereum?ps=100
# page written to file.
# Fetching Dragonereum tokens
# Fetching https://etherscan.io/tokens/label/dragonereum?ps=100
# page written to file.
# Fetching DutchX accounts
# Fetching https://etherscan.io/accounts/label/dutchx?ps=100
# page written to file.
# Fetching dYdX accounts
# Fetching https://etherscan.io/accounts/label/dydx?ps=100
# page written to file.
# Fetching E-Commerce accounts
# Fetching https://etherscan.io/accounts/label/e-commerce?ps=100
# page written to file.
# Fetching E-Commerce tokens
# Fetching https://etherscan.io/tokens/label/e-commerce?ps=100
# page written to file.
# Fetching Education accounts
# Fetching https://etherscan.io/accounts/label/education?ps=100
# page written to file.
# Fetching Education tokens
# Fetching https://etherscan.io/tokens/label/education?ps=100
# page written to file.
# Fetching Electricity tokens
# Fetching https://etherscan.io/tokens/label/electricity?ps=100
# page written to file.
# Fetching Electronics accounts
# Fetching https://etherscan.io/accounts/label/electronics?ps=100
# page written to file.
# Fetching Email tokens
# Fetching https://etherscan.io/tokens/label/email?ps=100
# page written to file.
# Fetching Energy Sector tokens
# Fetching https://etherscan.io/tokens/label/energy-sector?ps=100
# page written to file.
# Fetching ENS accounts
# Fetching https://etherscan.io/accounts/label/ens?ps=100
# page written to file.
# Fetching ENS tokens
# Fetching https://etherscan.io/tokens/label/ens?ps=100
# page written to file.
# Fetching Entertainment tokens
# Fetching https://etherscan.io/tokens/label/entertainment?ps=100
# page written to file.
# Fetching Escrow tokens
# Fetching https://etherscan.io/tokens/label/escrow?ps=100
# page written to file.
# Fetching Esports tokens
# Fetching https://etherscan.io/tokens/label/esports?ps=100
# page written to file.
# Fetching Etheremon accounts
# Fetching https://etherscan.io/accounts/label/etheremon?ps=100
# page written to file.
# Fetching Etheremon tokens
# Fetching https://etherscan.io/tokens/label/etheremon?ps=100
# page written to file.
# Fetching Ethereum Foundation accounts
# Fetching https://etherscan.io/accounts/label/ethereum-foundation?ps=100
# page written to file.
# Fetching Ethereum Foundation tokens
# Fetching https://etherscan.io/tokens/label/ethereum-foundation?ps=100
# page written to file.
# Fetching Ethereum Mixer accounts
# Fetching https://etherscan.io/accounts/label/ethereum-mixer?ps=100
# page written to file.
# Fetching Etheroll accounts
# Fetching https://etherscan.io/accounts/label/etheroll?ps=100
# page written to file.
# Fetching Etheroll tokens
# Fetching https://etherscan.io/tokens/label/etheroll?ps=100
# page written to file.
# Fetching Events tokens
# Fetching https://etherscan.io/tokens/label/events?ps=100
# page written to file.
# Fetching Exchange accounts
# Fetching https://etherscan.io/accounts/label/exchange/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/exchange/2?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/exchange/3?ps=100
# page written to file.
# Fetching Exchange tokens
# Fetching https://etherscan.io/tokens/label/exchange/1?ps=100
# page written to file.
# Fetching https://etherscan.io/tokens/label/exchange/2?ps=100
# page written to file.
# Fetching F2Pool accounts
# Fetching https://etherscan.io/accounts/label/f2pool?ps=100
# page written to file.
# Fetching Farming tokens
# Fetching https://etherscan.io/tokens/label/farming?ps=100
# page written to file.
# Fetching Fashion tokens
# Fetching https://etherscan.io/tokens/label/fashion?ps=100
# page written to file.
# Fetching FAT Brands Inc. accounts
# Fetching https://etherscan.io/accounts/label/fat-brands-inc?ps=100
# page written to file.
# Fetching FAT Brands Inc. tokens
# Fetching https://etherscan.io/tokens/label/fat-brands-inc?ps=100
# page written to file.
# Fetching Fiat Gateway accounts
# Fetching https://etherscan.io/accounts/label/fiat-gateway?ps=100
# page written to file.
# Fetching Fiat Gateway tokens
# Fetching https://etherscan.io/tokens/label/fiat-gateway?ps=100
# page written to file.
# Fetching Finance accounts
# Fetching https://etherscan.io/accounts/label/finance?ps=100
# page written to file.
# Fetching Finance tokens
# Fetching https://etherscan.io/tokens/label/finance?ps=100
# page written to file.
# Fetching Fintech tokens
# Fetching https://etherscan.io/tokens/label/fintech?ps=100
# page written to file.
# Fetching Fitness tokens
# Fetching https://etherscan.io/tokens/label/fitness?ps=100
# page written to file.
# Fetching Flagged by SEC accounts
# Fetching https://etherscan.io/accounts/label/flagged-by-sec?ps=100
# page written to file.
# Fetching Flagged by SEC tokens
# Fetching https://etherscan.io/tokens/label/flagged-by-sec?ps=100
# page written to file.
# Fetching Flexa accounts
# Fetching https://etherscan.io/accounts/label/flexa?ps=100
# page written to file.
# Fetching Flexa tokens
# Fetching https://etherscan.io/tokens/label/flexa?ps=100
# page written to file.
# Fetching Flowerpatch accounts
# Fetching https://etherscan.io/accounts/label/flowerpatch?ps=100
# page written to file.
# Fetching Flowerpatch tokens
# Fetching https://etherscan.io/tokens/label/flowerpatch?ps=100
# page written to file.
# Fetching FOAM accounts
# Fetching https://etherscan.io/accounts/label/foam?ps=100
# page written to file.
# Fetching FOAM tokens
# Fetching https://etherscan.io/tokens/label/foam?ps=100
# page written to file.
# Fetching Fomo3D accounts
# Fetching https://etherscan.io/accounts/label/fomo3d?ps=100
# page written to file.
# Fetching Freelance accounts
# Fetching https://etherscan.io/accounts/label/freelance?ps=100
# page written to file.
# Fetching Freelance tokens
# Fetching https://etherscan.io/tokens/label/freelance?ps=100
# page written to file.
# Fetching FTX accounts
# Fetching https://etherscan.io/accounts/label/ftx?ps=100
# page written to file.
# Fetching FTX tokens
# Fetching https://etherscan.io/tokens/label/ftx?ps=100
# page written to file.
# Fetching Fund tokens
# Fetching https://etherscan.io/tokens/label/fund?ps=100
# page written to file.
# Fetching Gambling accounts
# Fetching https://etherscan.io/accounts/label/gambling?ps=100
# page written to file.
# Fetching Gambling tokens
# Fetching https://etherscan.io/tokens/label/gambling?ps=100
# page written to file.
# Fetching Gaming accounts
# Fetching https://etherscan.io/accounts/label/gaming?ps=100
# page written to file.
# Fetching Gaming tokens
# Fetching https://etherscan.io/tokens/label/gaming/1?ps=100
# page written to file.
# Fetching https://etherscan.io/tokens/label/gaming/2?ps=100
# page written to file.
# Fetching Gas tokens
# Fetching https://etherscan.io/tokens/label/gas?ps=100
# page written to file.
# Fetching Gate.io accounts
# Fetching https://etherscan.io/accounts/label/gate-io?ps=100
# page written to file.
# Fetching GBX accounts
# Fetching https://etherscan.io/accounts/label/gbx?ps=100
# page written to file.
# Fetching GBX tokens
# Fetching https://etherscan.io/tokens/label/gbx?ps=100
# page written to file.
# Fetching Gemini accounts
# Fetching https://etherscan.io/accounts/label/gemini?ps=100
# page written to file.
# Fetching Gemini tokens
# Fetching https://etherscan.io/tokens/label/gemini?ps=100
# page written to file.
# Fetching Genesis accounts
# Fetching https://etherscan.io/accounts/label/genesis?ps=100
# page written to file.
# Fetching Gitcoin Grants accounts
# Fetching https://etherscan.io/accounts/label/gitcoin-grants/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/gitcoin-grants/2?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/gitcoin-grants/3?ps=100
# page written to file.
# Fetching Giveth.io accounts
# Fetching https://etherscan.io/accounts/label/giveth-io?ps=100
# page written to file.
# Fetching Gnosis Safe accounts
# Fetching https://etherscan.io/accounts/label/gnosis-safe?ps=100
# page written to file.
# Fetching Gods Unchained accounts
# Fetching https://etherscan.io/accounts/label/gods-unchained?ps=100
# page written to file.
# Fetching Gods Unchained tokens
# Fetching https://etherscan.io/tokens/label/gods-unchained?ps=100
# page written to file.
# Fetching Gold tokens
# Fetching https://etherscan.io/tokens/label/gold?ps=100
# page written to file.
# Fetching Governance tokens
# Fetching https://etherscan.io/tokens/label/governance?ps=100
# page written to file.
# Fetching HardForks blocks
# Fetching https://etherscan.io/blocks/label/hardforks?ps=100
# page written to file.
# Fetching Healthcare tokens
# Fetching https://etherscan.io/tokens/label/healthcare?ps=100
# page written to file.
# Fetching Heist accounts
# Fetching https://etherscan.io/accounts/label/heist?ps=100
# page written to file.
# Fetching HitBTC accounts
# Fetching https://etherscan.io/accounts/label/hitbtc?ps=100
# page written to file.
# Fetching Hot Wallet accounts
# Fetching https://etherscan.io/accounts/label/hot-wallet?ps=100
# page written to file.
# Fetching Hotbit accounts
# Fetching https://etherscan.io/accounts/label/hotbit?ps=100
# page written to file.
# Fetching Hotbit tokens
# Fetching https://etherscan.io/tokens/label/hotbit?ps=100
# page written to file.
# Fetching Hotel tokens
# Fetching https://etherscan.io/tokens/label/hotel?ps=100
# page written to file.
# Fetching HR tokens
# Fetching https://etherscan.io/tokens/label/hr?ps=100
# page written to file.
# Fetching Humanity accounts
# Fetching https://etherscan.io/accounts/label/humanity?ps=100
# page written to file.
# Fetching Huobi accounts
# Fetching https://etherscan.io/accounts/label/huobi?ps=100
# page written to file.
# Fetching Huobi tokens
# Fetching https://etherscan.io/tokens/label/huobi?ps=100
# page written to file.
# Fetching Hydro Protocol accounts
# Fetching https://etherscan.io/accounts/label/hydro-protocol?ps=100
# page written to file.
# Fetching Hydro Protocol tokens
# Fetching https://etherscan.io/tokens/label/hydro-protocol?ps=100
# page written to file.
# Fetching Hyper Dragons accounts
# Fetching https://etherscan.io/accounts/label/hyper-dragons?ps=100
# page written to file.
# Fetching Hyper Dragons tokens
# Fetching https://etherscan.io/tokens/label/hyper-dragons?ps=100
# page written to file.
# Fetching ICO Wallets accounts
# Fetching https://etherscan.io/accounts/label/ico-wallets/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/ico-wallets/2?ps=100
# page written to file.
# Fetching Identity tokens
# Fetching https://etherscan.io/tokens/label/identity?ps=100
# page written to file.
# Fetching IDEX accounts
# Fetching https://etherscan.io/accounts/label/idex?ps=100
# page written to file.
# Fetching IDEX tokens
# Fetching https://etherscan.io/tokens/label/idex?ps=100
# page written to file.
# Fetching iearn.finance accounts
# Fetching https://etherscan.io/accounts/label/iearn-finance?ps=100
# page written to file.
# Fetching iearn.finance tokens
# Fetching https://etherscan.io/tokens/label/iearn-finance?ps=100
# page written to file.
# Fetching Incubator tokens
# Fetching https://etherscan.io/tokens/label/incubator?ps=100
# page written to file.
# Fetching InstaDApp accounts
# Fetching https://etherscan.io/accounts/label/instadapp?ps=100
# page written to file.
# Fetching Insurance accounts
# Fetching https://etherscan.io/accounts/label/insurance?ps=100
# page written to file.
# Fetching Insurance tokens
# Fetching https://etherscan.io/tokens/label/insurance?ps=100
# page written to file.
# Fetching Insureum accounts
# Fetching https://etherscan.io/accounts/label/insureum?ps=100
# page written to file.
# Fetching Insureum tokens
# Fetching https://etherscan.io/tokens/label/insureum?ps=100
# page written to file.
# Fetching Interoperability / Cross-Chain tokens
# Fetching https://etherscan.io/tokens/label/interoperability-cross-chain?ps=100
# page written to file.
# Fetching Investment accounts
# Fetching https://etherscan.io/accounts/label/investment?ps=100
# page written to file.
# Fetching Investment tokens
# Fetching https://etherscan.io/tokens/label/investment?ps=100
# page written to file.
# Fetching Invoice Financing tokens
# Fetching https://etherscan.io/tokens/label/invoice-financing?ps=100
# page written to file.
# Fetching IoT tokens
# Fetching https://etherscan.io/tokens/label/iot?ps=100
# page written to file.
# Fetching Jobs tokens
# Fetching https://etherscan.io/tokens/label/jobs?ps=100
# page written to file.
# Fetching Knowledge tokens
# Fetching https://etherscan.io/tokens/label/knowledge?ps=100
# page written to file.
# Fetching Kraken accounts
# Fetching https://etherscan.io/accounts/label/kraken?ps=100
# page written to file.
# Fetching Kryptono accounts
# Fetching https://etherscan.io/accounts/label/kryptono?ps=100
# page written to file.
# Fetching Kryptono tokens
# Fetching https://etherscan.io/tokens/label/kryptono?ps=100
# page written to file.
# Fetching KuCoin accounts
# Fetching https://etherscan.io/accounts/label/kucoin?ps=100
# page written to file.
# Fetching KuCoin tokens
# Fetching https://etherscan.io/tokens/label/kucoin?ps=100
# page written to file.
# Fetching Kyber accounts
# Fetching https://etherscan.io/accounts/label/kyber?ps=100
# page written to file.
# Fetching Kyber tokens
# Fetching https://etherscan.io/tokens/label/kyber?ps=100
# page written to file.
# Fetching Land tokens
# Fetching https://etherscan.io/tokens/label/land?ps=100
# page written to file.
# Fetching LAToken accounts
# Fetching https://etherscan.io/accounts/label/latoken?ps=100
# page written to file.
# Fetching LAToken tokens
# Fetching https://etherscan.io/tokens/label/latoken?ps=100
# page written to file.
# Fetching Legal tokens
# Fetching https://etherscan.io/tokens/label/legal?ps=100
# page written to file.
# Fetching Liqui.io accounts
# Fetching https://etherscan.io/accounts/label/liqui.io?ps=100
# page written to file.
# Fetching Liquid accounts
# Fetching https://etherscan.io/accounts/label/liquid?ps=100
# page written to file.
# Fetching Liquid tokens
# Fetching https://etherscan.io/tokens/label/liquid?ps=100
# page written to file.
# Fetching Liquidity tokens
# Fetching https://etherscan.io/tokens/label/liquidity?ps=100
# page written to file.
# Fetching Loans accounts
# Fetching https://etherscan.io/accounts/label/loans?ps=100
# page written to file.
# Fetching Loans tokens
# Fetching https://etherscan.io/tokens/label/loans?ps=100
# page written to file.
# Fetching Logistics tokens
# Fetching https://etherscan.io/tokens/label/logistics?ps=100
# page written to file.
# Fetching Loopring accounts
# Fetching https://etherscan.io/accounts/label/loopring?ps=100
# page written to file.
# Fetching Loopring tokens
# Fetching https://etherscan.io/tokens/label/loopring?ps=100
# page written to file.
# Fetching LORDLESS accounts
# Fetching https://etherscan.io/accounts/label/lordless?ps=100
# page written to file.
# Fetching LORDLESS tokens
# Fetching https://etherscan.io/tokens/label/lordless?ps=100
# page written to file.
# Fetching Loyalty and Rewards tokens
# Fetching https://etherscan.io/tokens/label/loyalty-and-rewards?ps=100
# page written to file.
# Fetching LUKSO Blockchain accounts
# Fetching https://etherscan.io/accounts/label/lukso-blockchain?ps=100
# page written to file.
# Fetching LUKSO Blockchain tokens
# Fetching https://etherscan.io/tokens/label/lukso-blockchain?ps=100
# page written to file.
# Fetching Mainnet Launched tokens
# Fetching https://etherscan.io/tokens/label/mainnet-launched?ps=100
# page written to file.
# Fetching Maker accounts
# Fetching https://etherscan.io/accounts/label/maker?ps=100
# page written to file.
# Fetching Maker tokens
# Fetching https://etherscan.io/tokens/label/maker?ps=100
# page written to file.
# Fetching Manufacturing tokens
# Fetching https://etherscan.io/tokens/label/manufacturing?ps=100
# page written to file.
# Fetching Marketing tokens
# Fetching https://etherscan.io/tokens/label/marketing?ps=100
# page written to file.
# Fetching Marketplace accounts
# Fetching https://etherscan.io/accounts/label/marketplace?ps=100
# page written to file.
# Fetching Marketplace tokens
# Fetching https://etherscan.io/tokens/label/marketplace?ps=100
# page written to file.
# Fetching Masternode tokens
# Fetching https://etherscan.io/tokens/label/masternode?ps=100
# page written to file.
# Fetching Matic Network accounts
# Fetching https://etherscan.io/accounts/label/matic-network?ps=100
# page written to file.
# Fetching Matic Network tokens
# Fetching https://etherscan.io/tokens/label/matic-network?ps=100
# page written to file.
# Fetching Media accounts
# Fetching https://etherscan.io/accounts/label/media?ps=100
# page written to file.
# Fetching Media tokens
# Fetching https://etherscan.io/tokens/label/media?ps=100
# page written to file.
# Fetching MEDIKEY accounts
# Fetching https://etherscan.io/accounts/label/medikey?ps=100
# page written to file.
# Fetching MEDIKEY tokens
# Fetching https://etherscan.io/tokens/label/medikey?ps=100
# page written to file.
# Fetching MegaCryptoPolis accounts
# Fetching https://etherscan.io/accounts/label/megacryptopolis?ps=100
# page written to file.
# Fetching MegaCryptoPolis tokens
# Fetching https://etherscan.io/tokens/label/megacryptopolis?ps=100
# page written to file.
# Fetching Melon accounts
# Fetching https://etherscan.io/accounts/label/melon?ps=100
# page written to file.
# Fetching Melon tokens
# Fetching https://etherscan.io/tokens/label/melon?ps=100
# page written to file.
# Fetching MESG accounts
# Fetching https://etherscan.io/accounts/label/mesg?ps=100
# page written to file.
# Fetching MESG tokens
# Fetching https://etherscan.io/tokens/label/mesg?ps=100
# page written to file.
# Fetching Metronome accounts
# Fetching https://etherscan.io/accounts/label/metronome?ps=100
# page written to file.
# Fetching Metronome tokens
# Fetching https://etherscan.io/tokens/label/metronome?ps=100
# page written to file.
# Fetching Microtasking tokens
# Fetching https://etherscan.io/tokens/label/microtasking?ps=100
# page written to file.
# Fetching Mining accounts
# Fetching https://etherscan.io/accounts/label/mining?ps=100
# page written to file.
# Fetching Mining tokens
# Fetching https://etherscan.io/tokens/label/mining?ps=100
# page written to file.
# Fetching MiningPoolHub accounts
# Fetching https://etherscan.io/accounts/label/miningpoolhub?ps=100
# page written to file.
# Fetching Mobile tokens
# Fetching https://etherscan.io/tokens/label/mobile?ps=100
# page written to file.
# Fetching Movie / Film tokens
# Fetching https://etherscan.io/tokens/label/movie-film?ps=100
# page written to file.
# Fetching mStable accounts
# Fetching https://etherscan.io/accounts/label/mstable?ps=100
# page written to file.
# Fetching mStable tokens
# Fetching https://etherscan.io/tokens/label/mstable?ps=100
# page written to file.
# Fetching Music accounts
# Fetching https://etherscan.io/accounts/label/music?ps=100
# page written to file.
# Fetching Music tokens
# Fetching https://etherscan.io/tokens/label/music?ps=100
# page written to file.
# Fetching My Crypto Heroes accounts
# Fetching https://etherscan.io/accounts/label/my-crypto-heroes?ps=100
# page written to file.
# Fetching My Crypto Heroes tokens
# Fetching https://etherscan.io/tokens/label/my-crypto-heroes?ps=100
# page written to file.
# Fetching Neon District accounts
# Fetching https://etherscan.io/accounts/label/neon-district?ps=100
# page written to file.
# Fetching Neon District tokens
# Fetching https://etherscan.io/tokens/label/neon-district?ps=100
# page written to file.
# Fetching NEST Protocol accounts
# Fetching https://etherscan.io/accounts/label/nest-protocol?ps=100
# page written to file.
# Fetching NEST Protocol tokens
# Fetching https://etherscan.io/tokens/label/nest-protocol?ps=100
# page written to file.
# Fetching Network tokens
# Fetching https://etherscan.io/tokens/label/network?ps=100
# page written to file.
# Fetching News tokens
# Fetching https://etherscan.io/tokens/label/news?ps=100
# page written to file.
# Fetching Nexo accounts
# Fetching https://etherscan.io/accounts/label/nexo?ps=100
# page written to file.
# Fetching Nexo tokens
# Fetching https://etherscan.io/tokens/label/nexo?ps=100
# page written to file.
# Fetching NFT accounts
# Fetching https://etherscan.io/accounts/label/nft?ps=100
# page written to file.
# Fetching NFT tokens
# Fetching https://etherscan.io/tokens/label/nft?ps=100
# page written to file.
# Fetching Off-Chain tokens
# Fetching https://etherscan.io/tokens/label/off-chain?ps=100
# page written to file.
# Fetching Oil tokens
# Fetching https://etherscan.io/tokens/label/oil?ps=100
# page written to file.
# Fetching OKEx accounts
# Fetching https://etherscan.io/accounts/label/okex?ps=100
# page written to file.
# Fetching OKEx tokens
# Fetching https://etherscan.io/tokens/label/okex?ps=100
# page written to file.
# Fetching Old Contract accounts
# Fetching https://etherscan.io/accounts/label/old-contract/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/old-contract/2?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/old-contract/3?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/old-contract/4?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/old-contract/5?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/old-contract/6?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/old-contract/7?ps=100
# page written to file.
# Fetching Old Contract tokens
# Fetching https://etherscan.io/tokens/label/old-contract/1?ps=100
# page written to file.
# Fetching https://etherscan.io/tokens/label/old-contract/2?ps=100
# page written to file.
# Fetching https://etherscan.io/tokens/label/old-contract/3?ps=100
# page written to file.
# Fetching https://etherscan.io/tokens/label/old-contract/4?ps=100
# page written to file.
# Fetching Onyx.to accounts
# Fetching https://etherscan.io/accounts/label/onyx-to?ps=100
# page written to file.
# Fetching Onyx.to tokens
# Fetching https://etherscan.io/tokens/label/onyx-to?ps=100
# page written to file.
# Fetching OpenSea accounts
# Fetching https://etherscan.io/accounts/label/opensea?ps=100
# page written to file.
# Fetching Opium Team accounts
# Fetching https://etherscan.io/accounts/label/opium-team?ps=100
# page written to file.
# Fetching Options Trading accounts
# Fetching https://etherscan.io/accounts/label/options-trading?ps=100
# page written to file.
# Fetching Options Trading tokens
# Fetching https://etherscan.io/tokens/label/options-trading?ps=100
# page written to file.
# Fetching Oracle accounts
# Fetching https://etherscan.io/accounts/label/oracle?ps=100
# page written to file.
# Fetching Oracle tokens
# Fetching https://etherscan.io/tokens/label/oracle?ps=100
# page written to file.
# Fetching Orchid accounts
# Fetching https://etherscan.io/accounts/label/orchid?ps=100
# page written to file.
# Fetching Orchid tokens
# Fetching https://etherscan.io/tokens/label/orchid?ps=100
# page written to file.
# Fetching Origin Protocol accounts
# Fetching https://etherscan.io/accounts/label/origin-protocol?ps=100
# page written to file.
# Fetching Origin Protocol tokens
# Fetching https://etherscan.io/tokens/label/origin-protocol?ps=100
# page written to file.
# Fetching Origo accounts
# Fetching https://etherscan.io/accounts/label/origo?ps=100
# page written to file.
# Fetching Origo tokens
# Fetching https://etherscan.io/tokens/label/origo?ps=100
# page written to file.
# Fetching OTC accounts
# Fetching https://etherscan.io/accounts/label/otc?ps=100
# page written to file.
# Fetching OTC tokens
# Fetching https://etherscan.io/tokens/label/otc?ps=100
# page written to file.
# Fetching Others tokens
# Fetching https://etherscan.io/tokens/label/others?ps=100
# page written to file.
# Fetching Paribu accounts
# Fetching https://etherscan.io/accounts/label/paribu?ps=100
# page written to file.
# Fetching Parity Bug accounts
# Fetching https://etherscan.io/accounts/label/parity-bug/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/parity-bug/2?ps=100
# page written to file.
# Fetching Payment accounts
# Fetching https://etherscan.io/accounts/label/payment?ps=100
# page written to file.
# Fetching Payment tokens
# Fetching https://etherscan.io/tokens/label/payment?ps=100
# page written to file.
# Fetching Pet tokens
# Fetching https://etherscan.io/tokens/label/pet?ps=100
# page written to file.
# Fetching Platform tokens
# Fetching https://etherscan.io/tokens/label/platform/1?ps=100
# page written to file.
# Fetching https://etherscan.io/tokens/label/platform/2?ps=100
# page written to file.
# Fetching POA Network accounts
# Fetching https://etherscan.io/accounts/label/poa-network?ps=100
# page written to file.
# Fetching POA Network tokens
# Fetching https://etherscan.io/tokens/label/poa-network?ps=100
# page written to file.
# Fetching Poloniex accounts
# Fetching https://etherscan.io/accounts/label/poloniex?ps=100
# page written to file.
# Fetching PoolTogether accounts
# Fetching https://etherscan.io/accounts/label/pooltogether?ps=100
# page written to file.
# Fetching PoolTogether tokens
# Fetching https://etherscan.io/tokens/label/pooltogether?ps=100
# page written to file.
# Fetching Portfolio Tracker tokens
# Fetching https://etherscan.io/tokens/label/portfolio-tracker?ps=100
# page written to file.
# Fetching PoS tokens
# Fetching https://etherscan.io/tokens/label/pos?ps=100
# page written to file.
# Fetching Precious Metals tokens
# Fetching https://etherscan.io/tokens/label/precious-metals?ps=100
# page written to file.
# Fetching Prediction Market accounts
# Fetching https://etherscan.io/accounts/label/prediction-market?ps=100
# page written to file.
# Fetching Prediction Market tokens
# Fetching https://etherscan.io/tokens/label/prediction-market?ps=100
# page written to file.
# Fetching Privacy tokens
# Fetching https://etherscan.io/tokens/label/privacy?ps=100
# page written to file.
# Fetching Protocol tokens
# Fetching https://etherscan.io/tokens/label/protocol?ps=100
# page written to file.
# Fetching Proxy Contract accounts
# Fetching https://etherscan.io/accounts/label/proxy-contract?ps=100
# page written to file.
# Fetching Pundi X accounts
# Fetching https://etherscan.io/accounts/label/pundi-x?ps=100
# page written to file.
# Fetching Pundi X tokens
# Fetching https://etherscan.io/tokens/label/pundi-x?ps=100
# page written to file.
# Fetching QuadrigaCX accounts
# Fetching https://etherscan.io/accounts/label/quadrigacx?ps=100
# page written to file.
# Fetching Radio tokens
# Fetching https://etherscan.io/tokens/label/radio?ps=100
# page written to file.
# Fetching Raiden accounts
# Fetching https://etherscan.io/accounts/label/raiden?ps=100
# page written to file.
# Fetching Rating tokens
# Fetching https://etherscan.io/tokens/label/rating?ps=100
# page written to file.
# Fetching Real Estate accounts
# Fetching https://etherscan.io/accounts/label/real-estate?ps=100
# page written to file.
# Fetching Real Estate tokens
# Fetching https://etherscan.io/tokens/label/real-estate?ps=100
# page written to file.
# Fetching Remitano accounts
# Fetching https://etherscan.io/accounts/label/remitano?ps=100
# page written to file.
# Fetching Remittance  tokens
# Fetching https://etherscan.io/tokens/label/remittance+?ps=100
# page written to file.
# Fetching Remme accounts
# Fetching https://etherscan.io/accounts/label/remme?ps=100
# page written to file.
# Fetching Remme tokens
# Fetching https://etherscan.io/tokens/label/remme?ps=100
# page written to file.
# Fetching Ren accounts
# Fetching https://etherscan.io/accounts/label/ren?ps=100
# page written to file.
# Fetching Ren tokens
# Fetching https://etherscan.io/tokens/label/ren?ps=100
# page written to file.
# Fetching Rent tokens
# Fetching https://etherscan.io/tokens/label/rent?ps=100
# page written to file.
# Fetching Reputation tokens
# Fetching https://etherscan.io/tokens/label/reputation?ps=100
# page written to file.
# Fetching Research tokens
# Fetching https://etherscan.io/tokens/label/research?ps=100
# page written to file.
# Fetching Reserve Protocol accounts
# Fetching https://etherscan.io/accounts/label/reserve-protocol?ps=100
# page written to file.
# Fetching Reserve Protocol tokens
# Fetching https://etherscan.io/tokens/label/reserve-protocol?ps=100
# page written to file.
# Fetching Resfinex accounts
# Fetching https://etherscan.io/accounts/label/resfinex?ps=100
# page written to file.
# Fetching Resfinex tokens
# Fetching https://etherscan.io/tokens/label/resfinex?ps=100
# page written to file.
# Fetching Restaurant tokens
# Fetching https://etherscan.io/tokens/label/restaurant?ps=100
# page written to file.
# Fetching Retail tokens
# Fetching https://etherscan.io/tokens/label/retail?ps=100
# page written to file.
# Fetching Revain accounts
# Fetching https://etherscan.io/accounts/label/revain?ps=100
# page written to file.
# Fetching Revain tokens
# Fetching https://etherscan.io/tokens/label/revain?ps=100
# page written to file.
# Fetching Review tokens
# Fetching https://etherscan.io/tokens/label/review?ps=100
# page written to file.
# Fetching Ridesharing tokens
# Fetching https://etherscan.io/tokens/label/ridesharing?ps=100
# page written to file.
# Fetching Sablier accounts
# Fetching https://etherscan.io/accounts/label/sablier?ps=100
# page written to file.
# Fetching Scroll Network accounts
# Fetching https://etherscan.io/accounts/label/scroll-network?ps=100
# page written to file.
# Fetching Security accounts
# Fetching https://etherscan.io/accounts/label/security?ps=100
# page written to file.
# Fetching Security tokens
# Fetching https://etherscan.io/tokens/label/security?ps=100
# page written to file.
# Fetching Security Token tokens
# Fetching https://etherscan.io/tokens/label/security-token?ps=100
# page written to file.
# Fetching Sentinel Protocol accounts
# Fetching https://etherscan.io/accounts/label/sentinel-protocol?ps=100
# page written to file.
# Fetching Sentinel Protocol tokens
# Fetching https://etherscan.io/tokens/label/sentinel-protocol?ps=100
# page written to file.
# Fetching Services / Solutions tokens
# Fetching https://etherscan.io/tokens/label/services-solutions?ps=100
# page written to file.
# Fetching Set Protocol accounts
# Fetching https://etherscan.io/accounts/label/set-protocol/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/set-protocol/2?ps=100
# page written to file.
# Fetching Set Protocol tokens
# Fetching https://etherscan.io/tokens/label/set-protocol?ps=100
# page written to file.
# Fetching Set Social Trading tokens
# Fetching https://etherscan.io/tokens/label/set-social-trading?ps=100
# page written to file.
# Fetching ShapeShift accounts
# Fetching https://etherscan.io/accounts/label/shapeshift?ps=100
# page written to file.
# Fetching ShapeShift tokens
# Fetching https://etherscan.io/tokens/label/shapeshift?ps=100
# page written to file.
# Fetching Sharing tokens
# Fetching https://etherscan.io/tokens/label/sharing?ps=100
# page written to file.
# Fetching Shipping tokens
# Fetching https://etherscan.io/tokens/label/shipping?ps=100
# page written to file.
# Fetching Sidechains tokens
# Fetching https://etherscan.io/tokens/label/sidechains?ps=100
# page written to file.
# Fetching Silverway Platform accounts
# Fetching https://etherscan.io/accounts/label/silverway-platform?ps=100
# page written to file.
# Fetching Silverway Platform tokens
# Fetching https://etherscan.io/tokens/label/silverway-platform?ps=100
# page written to file.
# Fetching Smart Contract accounts
# Fetching https://etherscan.io/accounts/label/smart-contract?ps=100
# page written to file.
# Fetching Smart Contract tokens
# Fetching https://etherscan.io/tokens/label/smart-contract?ps=100
# page written to file.
# Fetching Social tokens
# Fetching https://etherscan.io/tokens/label/social?ps=100
# page written to file.
# Fetching Social Media tokens
# Fetching https://etherscan.io/tokens/label/social-media?ps=100
# page written to file.
# Fetching Software tokens
# Fetching https://etherscan.io/tokens/label/software?ps=100
# page written to file.
# Fetching Sports tokens
# Fetching https://etherscan.io/tokens/label/sports?ps=100
# page written to file.
# Fetching ST-20 tokens
# Fetching https://etherscan.io/tokens/label/st-20?ps=100
# page written to file.
# Fetching Stablecoin tokens
# Fetching https://etherscan.io/tokens/label/stablecoin?ps=100
# page written to file.
# Fetching Staking accounts
# Fetching https://etherscan.io/accounts/label/staking?ps=100
# page written to file.
# Fetching Staking tokens
# Fetching https://etherscan.io/tokens/label/staking?ps=100
# page written to file.
# Fetching Status accounts
# Fetching https://etherscan.io/accounts/label/status?ps=100
# page written to file.
# Fetching Status tokens
# Fetching https://etherscan.io/tokens/label/status?ps=100
# page written to file.
# Fetching Storage tokens
# Fetching https://etherscan.io/tokens/label/storage?ps=100
# page written to file.
# Fetching Streaming tokens
# Fetching https://etherscan.io/tokens/label/streaming?ps=100
# page written to file.
# Fetching Subscription / Membership tokens
# Fetching https://etherscan.io/tokens/label/subscription-membership?ps=100
# page written to file.
# Fetching Supply Chain tokens
# Fetching https://etherscan.io/tokens/label/supply-chain?ps=100
# page written to file.
# Fetching Surveillance tokens
# Fetching https://etherscan.io/tokens/label/surveillance?ps=100
# page written to file.
# Fetching Survey tokens
# Fetching https://etherscan.io/tokens/label/survey?ps=100
# page written to file.
# Fetching Swipe.io accounts
# Fetching https://etherscan.io/accounts/label/swipe-io?ps=100
# page written to file.
# Fetching Swipe.io tokens
# Fetching https://etherscan.io/tokens/label/swipe-io?ps=100
# page written to file.
# Fetching Switcheo accounts
# Fetching https://etherscan.io/accounts/label/switcheo?ps=100
# page written to file.
# Fetching Synthetix accounts
# Fetching https://etherscan.io/accounts/label/synthetix/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/synthetix/2?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/synthetix/3?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/synthetix/4?ps=100
# page written to file.
# Fetching Synthetix tokens
# Fetching https://etherscan.io/tokens/label/synthetix?ps=100
# page written to file.
# Fetching Syscoin accounts
# Fetching https://etherscan.io/accounts/label/syscoin?ps=100
# page written to file.
# Fetching TAGZ accounts
# Fetching https://etherscan.io/accounts/label/tagz?ps=100
# page written to file.
# Fetching TAGZ tokens
# Fetching https://etherscan.io/tokens/label/tagz?ps=100
# page written to file.
# Fetching tBTC accounts
# Fetching https://etherscan.io/accounts/label/tbtc?ps=100
# page written to file.
# Fetching tBTC tokens
# Fetching https://etherscan.io/tokens/label/tbtc?ps=100
# page written to file.
# Fetching Telecommunications tokens
# Fetching https://etherscan.io/tokens/label/telecommunications?ps=100
# page written to file.
# Fetching Ticketing tokens
# Fetching https://etherscan.io/tokens/label/ticketing?ps=100
# page written to file.
# Fetching Tidex accounts
# Fetching https://etherscan.io/accounts/label/tidex?ps=100
# page written to file.
# Fetching Token Contract accounts
# Fetching https://etherscan.io/accounts/label/token-contract/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/2?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/3?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/4?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/5?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/6?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/7?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/8?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/9?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/10?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/11?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/12?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/13?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/14?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/15?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/16?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/17?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/18?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/19?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/20?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/21?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/22?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/23?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/24?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/25?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/26?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-contract/27?ps=100
# page written to file.
# Fetching Token Migration tokens
# Fetching https://etherscan.io/tokens/label/token-migration?ps=100
# page written to file.
# Fetching Token Sale accounts
# Fetching https://etherscan.io/accounts/label/token-sale/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-sale/2?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-sale/3?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-sale/4?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/token-sale/5?ps=100
# page written to file.
# Fetching Tokenized Asset tokens
# Fetching https://etherscan.io/tokens/label/tokenized-asset?ps=100
# page written to file.
# Fetching Tokenized Equity tokens
# Fetching https://etherscan.io/tokens/label/tokenized-equity?ps=100
# page written to file.
# Fetching Tokenlon accounts
# Fetching https://etherscan.io/accounts/label/tokenlon?ps=100
# page written to file.
# Fetching Tokenlon tokens
# Fetching https://etherscan.io/tokens/label/tokenlon?ps=100
# page written to file.
# Fetching Tools tokens
# Fetching https://etherscan.io/tokens/label/tools?ps=100
# page written to file.
# Fetching TopBTC accounts
# Fetching https://etherscan.io/accounts/label/topbtc?ps=100
# page written to file.
# Fetching TopBTC tokens
# Fetching https://etherscan.io/tokens/label/topbtc?ps=100
# page written to file.
# Fetching Tornado.cash accounts
# Fetching https://etherscan.io/accounts/label/tornado-cash?ps=100
# page written to file.
# Fetching Trade.io accounts
# Fetching https://etherscan.io/accounts/label/trade-io?ps=100
# page written to file.
# Fetching Trade.io tokens
# Fetching https://etherscan.io/tokens/label/trade-io?ps=100
# page written to file.
# Fetching Trading accounts
# Fetching https://etherscan.io/accounts/label/trading?ps=100
# page written to file.
# Fetching Trading tokens
# Fetching https://etherscan.io/tokens/label/trading?ps=100
# page written to file.
# Fetching Transportation tokens
# Fetching https://etherscan.io/tokens/label/transportation?ps=100
# page written to file.
# Fetching Travel tokens
# Fetching https://etherscan.io/tokens/label/travel?ps=100
# page written to file.
# Fetching TrustToken accounts
# Fetching https://etherscan.io/accounts/label/trusttoken?ps=100
# page written to file.
# Fetching TrustToken tokens
# Fetching https://etherscan.io/tokens/label/trusttoken?ps=100
# page written to file.
# Fetching Uniswap accounts
# Fetching https://etherscan.io/accounts/label/uniswap/1?ps=100
# page written to file.
# Fetching https://etherscan.io/accounts/label/uniswap/2?ps=100
# page written to file.
# Fetching Upbit accounts
# Fetching https://etherscan.io/accounts/label/upbit?ps=100
# page written to file.
# Fetching Vehicle tokens
# Fetching https://etherscan.io/tokens/label/vehicle?ps=100
# page written to file.
# Fetching Video tokens
# Fetching https://etherscan.io/tokens/label/video?ps=100
# page written to file.
# Fetching Vodi X accounts
# Fetching https://etherscan.io/accounts/label/vodi-x?ps=100
# page written to file.
# Fetching Vodi X tokens
# Fetching https://etherscan.io/tokens/label/vodi-x?ps=100
# page written to file.
# Fetching VPN tokens
# Fetching https://etherscan.io/tokens/label/vpn?ps=100
# page written to file.
# Fetching VR tokens
# Fetching https://etherscan.io/tokens/label/vr?ps=100
# page written to file.
# Fetching Wallet App accounts
# Fetching https://etherscan.io/accounts/label/wallet-app?ps=100
# page written to file.
# Fetching Wallet App tokens
# Fetching https://etherscan.io/tokens/label/wallet-app?ps=100
# page written to file.
# Fetching White Hat Group accounts
# Fetching https://etherscan.io/accounts/label/white-hat-group?ps=100
# page written to file.
# Fetching Wi-Fi tokens
# Fetching https://etherscan.io/tokens/label/wi-fi?ps=100
# page written to file.
# Fetching YUNBI accounts
# Fetching https://etherscan.io/accounts/label/yunbi?ps=100
# page written to file.
# Fetching Zapper.Fi accounts
# Fetching https://etherscan.io/accounts/label/zapper-fi?ps=100
# page written to file.
# Fetching ZB.com accounts
# Fetching https://etherscan.io/accounts/label/zb-com?ps=100
# page written to file.
# Fetching ZB.com tokens
# Fetching https://etherscan.io/tokens/label/zb-com?ps=100
# page written to file.
# Fetching Zerion accounts
# Fetching https://etherscan.io/accounts/label/zerion?ps=100
# page written to file.
# Fetching Zethr accounts
# Fetching https://etherscan.io/accounts/label/zethr?ps=100
# page written to file.
# Fetching Zethr tokens
# Fetching https://etherscan.io/tokens/label/zethr?ps=100
# page written to file.
# finished.

# %%
legit_csv = "legit.csv"
write_list_as_row(legit_csv, [])
