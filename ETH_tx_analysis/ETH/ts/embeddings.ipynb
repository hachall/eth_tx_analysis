# %%
import csv
import time 
import datetime
from statistics import mean, stdev
from dateutil import parser
import numpy as np

# %%
class Node():
    
    def __init__(self, addr, name, acc_type, contract_type, entity, label, tags = []):
        self.addr = addr
        self.name = name
        self.acc_type = acc_type
        self.contract_type = contract_type
        self.entity = entity
        self.label = label
        self.tags = tags      
        self.txs_in = []
        self.txs_out = []
        
    def add_tx_in(self, tx):
        self.txs_in.append(tx)
        
    def add_tx_out(self, tx):
        self.txs_out.append(tx)
        
    def feature_vec(self):
        vec = [0] * 8
        type_indexes = {'Wallet': 0, 'Smart Contract': 1}
        
        vec[type_indexes[self.acc_type]] = 1
        
        if self.contract_type == 'Token':
            vec[2] = 1
            
        if self.entity:
            entity_indexes = {'Exchange': 3, 'Dex': 4, 'ICO Wallets': 5, 'Mining': 6, 'DeFi': 7}
            vec[entity_indexes[self.entity]] = 1
        
        return vec
            
        
    def __str__(self):
        return f"{self.addr} - {self.name} \n{self.acc_type}, {self.entity}, {self.contract_type}"

# %%
class Tx():
    #A transaction is a transfer of ether, a contract invocation, or contract creation
    def __init__(self, tx_type, block_num, timestamp, sender, receiver, value, gasLim, gasUsed, gasPrice, isError, code):
        self.tx_type = tx_type
        self.block_num = block_num
        self.timestamp = timestamp
        self.sender = sender
        self.receiver = receiver
        self.value = value
        self.gasLim = gasLim
        self.gasUsed = gasUsed
        self.gasPrice = gasPrice
        self.isError = isError
        self.code = code
    
    def edge_vec(self):
        vec = [0] * 8
        
        type_indexes = {'Transfer': 0, 'Contract Invocation': 1, 'Contract Creation': 2}
        vec[type_indexes[self.tx_type]] = 1
        
        vec[3] = self.value
        vec[4] = self.gasLim
        vec[5] = self.gasUsed
        vec[6] = self.gasPrice
        vec[7] = self.isError
        
        return vec
    
    def __str__(self):
        return f"{self.value} ETH from {self.sender} to {self.receiver} at {self.timestamp}"

# %%
def parse_node_row(row):
    return row[0], row[1], row[2], row[3], row[4], row[5], [x for x in row[6:] if x]

def parse_tx_row(row):
    code = row[13]
    
    if code == '0x' or int(code, 0) == 0:
        tx_type = 'Transfer'
        
    else:
        tx_type = 'Contract Invocation'
    
    sender, receiver = row[6], row[7]
    if receiver == '':
        tx_type = 'Contract Creation'
        receiver = row[14]
    
    d = datetime.datetime.fromtimestamp(int(row[1]))
    
    return tx_type, row[0], d, sender, receiver, float(row[8]), int(row[9]), int(row[16]), int(row[10]), int(row[11]), code

# %%
#Fetch reference nodes
reference_nodes = {}
with open("final.csv") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter = ',')
    line_count = 0
    
    for row in csv_reader:
        
        if line_count == 0:
            line_count += 1 
            continue
        else:
            addr, name, acc_type, contract_type, entity, label, tags = parse_node_row(row)
            reference_nodes[row[0]] = Node(addr, name, acc_type, contract_type, entity, label, tags)

# %%
#Fetch transactions
txs = []
with open('2019-2-11-to-2019-4-11-txs-byN.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter = ',')
    line_count = 0
    
    for row in csv_reader:
        
        if line_count == 0:
            line_count += 1
            continue
        else:
            tx_type, block_num, timestamp, sender, receiver, value, gasSent, gasUsed, gasPrice, isError, code = parse_tx_row(row)
            txs.append(Tx(tx_type, block_num, timestamp, sender, receiver, value, gasSent, gasUsed, gasPrice, isError, code))

        
txs.sort(key = lambda x: x.timestamp)

# %%
#Only external transactions retrieved (from blockchain), so senders must be EOAs
senders = set()
for tx in txs:
    senders.add(tx.sender)
    
for tx in txs:
    if tx.tx_type == 'Contract Invocation' and tx.receiver in senders:
        tx.tx_type = 'Transfer'
        
#Need to use etherscan if want to fetch internal transactions

# %%
types= {
    'Transfer': 0,
    'Contract Creation': 0,
    'Contract Invocation': 0
}
for tx in txs:
    types[tx.tx_type] +=1
    
print(types)
# Out:
# {'Transfer': 404904, 'Contract Creation': 2225, 'Contract Invocation': 330602}

# %%
#Turn transaction list into a nodelist

# %%
nodes = {}
for tx in txs:
    
    sender, receiver = tx.sender, tx.receiver
    
    if sender in nodes.keys():
        nodes[sender].add_tx_out(tx)
    else:
        if sender in reference_nodes.keys():
            nodes[sender] = reference_nodes[sender]
            nodes[sender].add_tx_out(tx)
        else:
            nodes[sender] = Node(sender, '', 'Wallet', '', '', 'Unlabelled')
            nodes[sender].add_tx_out(tx)
        
        
    if receiver in nodes.keys():
        nodes[receiver].add_tx_in(tx)
    else:
        if receiver in reference_nodes.keys():
            nodes[receiver] = reference_nodes[receiver]
            nodes[receiver].add_tx_in(tx)
        else:
            nodes[receiver] = Node(receiver, '', 'Wallet' if tx.tx_type == 'Transfer' else 'Smart Contract', '', '', 'Unlabelled')
            nodes[receiver].add_tx_in(tx)

# %%
#Shuffle the nodes and then assign node numbers - so graphs are roughly same size (means v sparse)
import random
keys = list(nodes.keys())
random.shuffle(keys)
for i, addr in enumerate(keys):
    nodes[addr].node_id = i

# %%
lim = 0
# self.addr = addr
#         self.name = name
#         self.acc_type = acc_type
#         self.contract_type = contract_type
#         self.entity = entity
#         self.label = label
#         self.tags = tags 
ls = {
    'Dodgy': 0,
    'Legit': 0,
    'Unlabelled': 0
}
tos = {
    'Token': 0,
    '': 0
}
ts = {
    'Wallet': 0,
    'Smart Contract': 0
}
es = {
    'Dex': 0,
    'Exchange': 0,
    'ICO Wallets': 0,
    'Mining': 0,
    'DeFi': 0,
    '': 0
}

for node in nodes.values():
    if lim == 100:
        print(node)
        print(node.node_id)
        print(node.feature_vec())
        lim += 1
    
    ls[node.label] += 1
    tos[node.contract_type] += 1
    es[node.entity] += 1
    ts[node.acc_type] += 1
    
    
print(ls)
print(ts)
print(es)
print(tos)
# Out:
# {'Dodgy': 126, 'Legit': 1045, 'Unlabelled': 273002}
# {'Wallet': 262305, 'Smart Contract': 11868}
# {'Dex': 16, 'Exchange': 112, 'ICO Wallets': 8, 'Mining': 26, 'DeFi': 27, '': 273984}
# {'Token': 709, '': 273464}

# %%
#Need to normalize edge features before splitting into sub graphs, for consistency across graphs
vec_length = len(txs[0].edge_vec())
maxs = txs[0].edge_vec()
mins = txs[0].edge_vec()

for tx in txs:
    vec = tx.edge_vec()
    
    for i in range(vec_length):
        maxs[i] = vec[i] if vec[i] > maxs[i] else maxs[i]
        mins[i] = vec[i] if vec[i] < mins[i] else mins[i]
        
maxs = np.array(maxs)
mins = np.array(mins)

# %%
def split_txs(txs, splitter):
    return splitter(txs)

# %%
def split_by_day(txs):
    
    txs_by_day = {}
    
    for tx in txs:
        date_str = str(tx.timestamp.month) + '/' + str(tx.timestamp.day)
        
        if date_str in txs_by_day.keys():
            txs_by_day[date_str].append(tx)
        else:
            txs_by_day[date_str] = [tx]
        
    return txs_by_day

# %%
txs_dict = split_txs(txs, split_by_day)
del txs_dict['2/10'] #first day is not a full day

# %%
print(mins)
print(maxs)
# Out:
# [    0.     0.     0.     0. 21000. 14150.     0.     0.]
# [1.000000e+00 1.000000e+00 1.000000e+00 5.000000e+22 8.000000e+06
#  7.614876e+06 3.999900e+13 1.000000e+00]

# %%
import torch
from torch_geometric.data import Data

# %%
demo_node = next(iter(nodes.values()))
feat_length = len(demo_node.feature_vec())

feats = torch.zeros(len(nodes), feat_length, dtype=torch.float)

# %%
for node in nodes.values():
    feats[node.node_id] = torch.FloatTensor(node.feature_vec())

# %%
def normalize(maxs, mins, vec):
    return (vec - mins) / (maxs - mins)

def denormalize(maxs, mins, vec):
    return vec * (maxs - mins) + mins

# %%
def make_subgraph(tx_list, feats):
    l = len(tx_list)
    u = torch.zeros([l,1], dtype=torch.long)
    v = torch.zeros([l,1], dtype=torch.long)
    e = torch.zeros([l,vec_length], dtype=torch.float32)
    
    edges = {}
    count = 0
    for i, tx in enumerate(tx_list):
        if nodes[tx.sender].node_id not in edges.keys():
            edges[nodes[tx.sender].node_id] = count
            count += 1 
            
        if nodes[tx.receiver].node_id not in edges.keys():
            edges[nodes[tx.receiver].node_id] = count
            count += 1 
            
        u[i] = edges[nodes[tx.sender].node_id]
        v[i] = edges[nodes[tx.receiver].node_id]
        e[i] = torch.FloatTensor(tx.edge_vec())
        
    e = normalize(maxs, mins, e)    
    edge_index = torch.stack((u.t(), v.t()), dim=0)
    edge_index = edge_index.squeeze()
    
    mask = list(edges.keys())
    
    g = Data(x=feats[mask], edge_index=edge_index, edge_attr=e)
    
    return g, mask

# %%
graphs = {}
for incr in txs_dict.keys():
    graphs[incr], _ = make_subgraph(txs_dict[incr], feats)

# %%
graphs
# Out:
# {'2/11': Data(edge_attr=[55943, 8], edge_index=[2, 55943], x=[34914, 8]),
#  '2/12': Data(edge_attr=[39643, 8], edge_index=[2, 39643], x=[22388, 8]),
#  '2/13': Data(edge_attr=[35093, 8], edge_index=[2, 35093], x=[20215, 8]),
#  '2/14': Data(edge_attr=[31703, 8], edge_index=[2, 31703], x=[19179, 8]),
#  '2/15': Data(edge_attr=[32583, 8], edge_index=[2, 32583], x=[18286, 8]),
#  '2/16': Data(edge_attr=[26403, 8], edge_index=[2, 26403], x=[13754, 8]),
#  '2/17': Data(edge_attr=[21063, 8], edge_index=[2, 21063], x=[10902, 8]),
#  '2/18': Data(edge_attr=[21593, 8], edge_index=[2, 21593], x=[11609, 8]),
#  '2/19': Data(edge_attr=[21727, 8], edge_index=[2, 21727], x=[11974, 8]),
#  '2/20': Data(edge_attr=[18630, 8], edge_index=[2, 18630], x=[10285, 8]),
#  '2/21': Data(edge_attr=[14732, 8], edge_index=[2, 14732], x=[8005, 8]),
#  '2/22': Data(edge_attr=[13271, 8], edge_index=[2, 13271], x=[7839, 8]),
#  '2/23': Data(edge_attr=[12373, 8], edge_index=[2, 12373], x=[7375, 8]),
#  '2/24': Data(edge_attr=[12805, 8], edge_index=[2, 12805], x=[7376, 8]),
#  '2/25': Data(edge_attr=[13057, 8], edge_index=[2, 13057], x=[8041, 8]),
#  '2/26': Data(edge_attr=[14290, 8], edge_index=[2, 14290], x=[8056, 8]),
#  '2/27': Data(edge_attr=[15550, 8], edge_index=[2, 15550], x=[10126, 8]),
#  '2/28': Data(edge_attr=[13362, 8], edge_index=[2, 13362], x=[8557, 8]),
#  '3/1': Data(edge_attr=[12853, 8], edge_index=[2, 12853], x=[7685, 8]),
#  '3/2': Data(edge_attr=[10300, 8], edge_index=[2, 10300], x=[6167, 8]),
#  '3/3': Data(edge_attr=[7792, 8], edge_index=[2, 7792], x=[4980, 8]),
#  '3/4': Data(edge_attr=[13929, 8], edge_index=[2, 13929], x=[9501, 8]),
#  '3/5': Data(edge_attr=[13166, 8], edge_index=[2, 13166], x=[6531, 8]),
#  '3/6': Data(edge_attr=[12019, 8], edge_index=[2, 12019], x=[9242, 8]),
#  '3/7': Data(edge_attr=[8855, 8], edge_index=[2, 8855], x=[5741, 8]),
#  '3/8': Data(edge_attr=[10445, 8], edge_index=[2, 10445], x=[6280, 8]),
#  '3/9': Data(edge_attr=[8993, 8], edge_index=[2, 8993], x=[5142, 8]),
#  '3/10': Data(edge_attr=[7261, 8], edge_index=[2, 7261], x=[4543, 8]),
#  '3/11': Data(edge_attr=[8835, 8], edge_index=[2, 8835], x=[5590, 8]),
#  '3/12': Data(edge_attr=[12586, 8], edge_index=[2, 12586], x=[8871, 8]),
#  '3/13': Data(edge_attr=[16105, 8], edge_index=[2, 16105], x=[12264, 8]),
#  '3/14': Data(edge_attr=[14544, 8], edge_index=[2, 14544], x=[7070, 8]),
#  '3/15': Data(edge_attr=[10772, 8], edge_index=[2, 10772], x=[6925, 8]),
#  '3/16': Data(edge_attr=[8559, 8], edge_index=[2, 8559], x=[4827, 8]),
#  '3/17': Data(edge_attr=[7680, 8], edge_index=[2, 7680], x=[4113, 8]),
#  '3/18': Data(edge_attr=[10163, 8], edge_index=[2, 10163], x=[5026, 8]),
#  '3/19': Data(edge_attr=[10389, 8], edge_index=[2, 10389], x=[5449, 8]),
#  '3/20': Data(edge_attr=[9224, 8], edge_index=[2, 9224], x=[5372, 8]),
#  '3/21': Data(edge_attr=[7452, 8], edge_index=[2, 7452], x=[4657, 8]),
#  '3/22': Data(edge_attr=[6666, 8], edge_index=[2, 6666], x=[4405, 8]),
#  '3/23': Data(edge_attr=[5456, 8], edge_index=[2, 5456], x=[3649, 8]),
#  '3/24': Data(edge_attr=[5284, 8], edge_index=[2, 5284], x=[3527, 8]),
#  '3/25': Data(edge_attr=[6170, 8], edge_index=[2, 6170], x=[4201, 8]),
#  '3/26': Data(edge_attr=[5207, 8], edge_index=[2, 5207], x=[3723, 8]),
#  '3/27': Data(edge_attr=[5174, 8], edge_index=[2, 5174], x=[3673, 8]),
#  '3/28': Data(edge_attr=[5240, 8], edge_index=[2, 5240], x=[3523, 8]),
#  '3/29': Data(edge_attr=[5191, 8], edge_index=[2, 5191], x=[3599, 8]),
#  '3/30': Data(edge_attr=[4060, 8], edge_index=[2, 4060], x=[2935, 8]),
#  '3/31': Data(edge_attr=[3863, 8], edge_index=[2, 3863], x=[2718, 8]),
#  '4/1': Data(edge_attr=[5236, 8], edge_index=[2, 5236], x=[3653, 8]),
#  '4/2': Data(edge_attr=[6345, 8], edge_index=[2, 6345], x=[4461, 8]),
#  '4/3': Data(edge_attr=[6287, 8], edge_index=[2, 6287], x=[4253, 8]),
#  '4/4': Data(edge_attr=[5007, 8], edge_index=[2, 5007], x=[3466, 8]),
#  '4/5': Data(edge_attr=[4173, 8], edge_index=[2, 4173], x=[3015, 8]),
#  '4/6': Data(edge_attr=[3707, 8], edge_index=[2, 3707], x=[2709, 8]),
#  '4/7': Data(edge_attr=[4616, 8], edge_index=[2, 4616], x=[3517, 8]),
#  '4/8': Data(edge_attr=[5356, 8], edge_index=[2, 5356], x=[3899, 8]),
#  '4/9': Data(edge_attr=[4335, 8], edge_index=[2, 4335], x=[3157, 8]),
#  '4/10': Data(edge_attr=[4610, 8], edge_index=[2, 4610], x=[3262, 8])}

# %%
def node_to_address(node_num):
    for node in nodes.values():
        if node.node_id == node_num:
            return node.addr
        
    return ''

# %%
import torch
import torch.nn.functional as F
import torch_geometric.transforms as T
from torch_geometric.nn import GCNConv, GAE, VGAE
from torch_geometric.utils import train_test_split_edges, remove_isolated_nodes, to_dense_adj

# %%
class Encoder(torch.nn.Module):
    def __init__(self, model_type, in_channels, out_channels):
        super(Encoder, self).__init__()
        self.model_type = model_type
        self.conv1 = GCNConv(in_channels, 2 * out_channels, cached=False)
        if self.model_type in ['GAE']:
            self.conv2 = GCNConv(2 * out_channels, out_channels, cached=False)
        elif self.model_type in ['VGAE']:
            self.conv_mu = GCNConv(2 * out_channels, out_channels, cached=False)
            self.conv_logstd = GCNConv(2 * out_channels, out_channels,
                                       cached=False)

    def forward(self, x, edge_index):
        x = F.relu(self.conv1(x, edge_index))
        if self.model_type in ['GAE']:
            return self.conv2(x, edge_index)
        elif self.model_type in ['VGAE']:
            return self.conv_mu(x, edge_index), self.conv_logstd(x, edge_index)

# %%
def setup_ae_model(model_type, in_features, embed_dims):
    model_options = {'GAE': GAE, 'VGAE': VGAE}
    dev = torch.device('cuda:0')
    model = model_options[model_type](Encoder(model_type, in_features, embed_dims)).to(dev)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    return model, optimizer

# %%
def graph_split(g_list): 
    for g in g_list.values():
        g = train_test_split_edges(g)
    
def data_to_device(g, dev):
    x, train_pos_edge_index = g.x.to(dev), g.train_pos_edge_index.to(dev)
    return x, train_pos_edge_index

# %%
def train_gae(model, model_type, optimizer, graph_list, dev):
    model.train()
    optimizer.zero_grad()
    

    keys = list(graph_list.keys())
    random.shuffle(keys)
    
    for key in keys:
        graph = graph_list[key]
        x, train_pos_edge_index = data_to_device(graph, dev)
        z = model.encode(x, train_pos_edge_index)
        loss = model.recon_loss(z, train_pos_edge_index)
        if model_type in ['VGAE']:
            loss = loss + (1 / data.num_nodes) * model.kl_loss()
            
    loss.backward()
    optimizer.step()

# %%
def test_gae(model, graph_list, dev):
    dev = torch.device('cuda:0')
    AUC = 0
    AP = 0
    model.eval()
    with torch.no_grad():
        for graph in graph_list.values():
            z = model.encode(graph.x.to(dev), graph.train_pos_edge_index.to(dev))
            auc, ap = model.test(z, graph.test_pos_edge_index, graph.test_neg_edge_index)
            AUC += auc
            AP += ap
           
    N = len(graph_list)
    return AUC/N, AP/N

# %%
t = 'GAE'
model, optimizer = setup_ae_model(t, 8, 16)
graph_split(graphs)
for epoch in range(1001):
    print(f"Epoch {epoch}")
    train_gae(model, 'GAE', optimizer, graphs, 'cuda:0')
    auc, ap = test_gae(model, graphs, 'cuda')
    print('Epoch: {:03d}, AUC: {:.4f}, AP: {:.4f}'.format(epoch, auc, ap))
# Out:
# Epoch 0
# Epoch: 000, AUC: 0.8898, AP: 0.9231
# Epoch 1
# Epoch: 001, AUC: 0.9410, AP: 0.9539
# Epoch 2
# Epoch: 002, AUC: 0.9592, AP: 0.9662
# Epoch 3
# Epoch: 003, AUC: 0.9660, AP: 0.9701
# Epoch 4
# Epoch: 004, AUC: 0.9711, AP: 0.9728
# Epoch 5
# Epoch: 005, AUC: 0.9748, AP: 0.9751
# Epoch 6
# Epoch: 006, AUC: 0.9756, AP: 0.9755
# Epoch 7
# Epoch: 007, AUC: 0.9754, AP: 0.9760
# Epoch 8
# Epoch: 008, AUC: 0.9751, AP: 0.9757
# Epoch 9
# Epoch: 009, AUC: 0.9757, AP: 0.9750
# Epoch 10
# Epoch: 010, AUC: 0.9742, AP: 0.9737
# Epoch 11
# Epoch: 011, AUC: 0.9722, AP: 0.9727
# Epoch 12
# Epoch: 012, AUC: 0.9719, AP: 0.9729
# Epoch 13
# Epoch: 013, AUC: 0.9731, AP: 0.9736
# Epoch 14
# Epoch: 014, AUC: 0.9753, AP: 0.9741
# Epoch 15
# Epoch: 015, AUC: 0.9746, AP: 0.9749
# Epoch 16
# Epoch: 016, AUC: 0.9757, AP: 0.9747
# Epoch 17
# Epoch: 017, AUC: 0.9728, AP: 0.9741
# Epoch 18
# Epoch: 018, AUC: 0.9696, AP: 0.9717
# Epoch 19
# Epoch: 019, AUC: 0.9663, AP: 0.9709
# Epoch 20
# Epoch: 020, AUC: 0.9649, AP: 0.9702
# Epoch 21
# Epoch: 021, AUC: 0.9653, AP: 0.9696
# Epoch 22
# Epoch: 022, AUC: 0.9653, AP: 0.9699
# Epoch 23
# Epoch: 023, AUC: 0.9650, AP: 0.9709
# Epoch 24
# Epoch: 024, AUC: 0.9666, AP: 0.9709
# Epoch 25
# Epoch: 025, AUC: 0.9671, AP: 0.9713
# Epoch 26
# Epoch: 026, AUC: 0.9665, AP: 0.9718
# Epoch 27
# Epoch: 027, AUC: 0.9664, AP: 0.9710
# Epoch 28
# Epoch: 028, AUC: 0.9650, AP: 0.9707
# Epoch 29
# Epoch: 029, AUC: 0.9645, AP: 0.9701
# Epoch 30
# Epoch: 030, AUC: 0.9643, AP: 0.9697
# Epoch 31
# Epoch: 031, AUC: 0.9650, AP: 0.9692
# Epoch 32
# Epoch: 032, AUC: 0.9657, AP: 0.9697
# Epoch 33
# Epoch: 033, AUC: 0.9658, AP: 0.9703
# Epoch 34
# Epoch: 034, AUC: 0.9664, AP: 0.9704
# Epoch 35
# Epoch: 035, AUC: 0.9646, AP: 0.9695
# Epoch 36
# Epoch: 036, AUC: 0.9627, AP: 0.9674
# Epoch 37
# Epoch: 037, AUC: 0.9594, AP: 0.9662
# Epoch 38
# Epoch: 038, AUC: 0.9606, AP: 0.9666
# Epoch 39
# Epoch: 039, AUC: 0.9622, AP: 0.9688
# Epoch 40
# Epoch: 040, AUC: 0.9647, AP: 0.9698
# Epoch 41
# Epoch: 041, AUC: 0.9644, AP: 0.9696
# Epoch 42
# Epoch: 042, AUC: 0.9622, AP: 0.9691
# Epoch 43
# Epoch: 043, AUC: 0.9594, AP: 0.9661
# Epoch 44
# Epoch: 044, AUC: 0.9531, AP: 0.9619
# Epoch 45
# Epoch: 045, AUC: 0.9475, AP: 0.9585
# Epoch 46
# Epoch: 046, AUC: 0.9406, AP: 0.9543
# Epoch 47
# Epoch: 047, AUC: 0.9448, AP: 0.9568
# Epoch 48
# Epoch: 048, AUC: 0.9507, AP: 0.9617
# Epoch 49
# Epoch: 049, AUC: 0.9562, AP: 0.9647
# Epoch 50
# Epoch: 050, AUC: 0.9591, AP: 0.9662
# Epoch 51
# Epoch: 051, AUC: 0.9572, AP: 0.9646
# Epoch 52
# Epoch: 052, AUC: 0.9516, AP: 0.9604
# Epoch 53
# Epoch: 053, AUC: 0.9446, AP: 0.9551
# Epoch 54
# Epoch: 054, AUC: 0.9417, AP: 0.9529
# Epoch 55
# Epoch: 055, AUC: 0.9446, AP: 0.9549
# Epoch 56
# Epoch: 056, AUC: 0.9472, AP: 0.9568
# Epoch 57
# Epoch: 057, AUC: 0.9462, AP: 0.9559
# Epoch 58
# Epoch: 058, AUC: 0.9416, AP: 0.9537
# Epoch 59
# Epoch: 059, AUC: 0.9408, AP: 0.9524
# Epoch 60
# Epoch: 060, AUC: 0.9338, AP: 0.9478
# Epoch 61
# Epoch: 061, AUC: 0.9291, AP: 0.9445
# Epoch 62
# Epoch: 062, AUC: 0.9233, AP: 0.9401
# Epoch 63
# Epoch: 063, AUC: 0.9252, AP: 0.9407
# Epoch 64
# Epoch: 064, AUC: 0.9226, AP: 0.9384
# Epoch 65
# Epoch: 065, AUC: 0.9272, AP: 0.9405
# Epoch 66
# Epoch: 066, AUC: 0.9345, AP: 0.9447
# Epoch 67
# Epoch: 067, AUC: 0.9295, AP: 0.9400
# Epoch 68
# Epoch: 068, AUC: 0.8391, AP: 0.8638
# Epoch 69
# Epoch: 069, AUC: 0.5312, AP: 0.7085
# Epoch 70
# Epoch: 070, AUC: 0.5193, AP: 0.7041
# Epoch 71
# Epoch: 071, AUC: 0.5200, AP: 0.7042
# Epoch 72
# Epoch: 072, AUC: 0.5411, AP: 0.7108
# Epoch 73
# Epoch: 073, AUC: 0.6380, AP: 0.7471
# Epoch 74
# Epoch: 074, AUC: 0.6844, AP: 0.7728
# Epoch 75
# Epoch: 075, AUC: 0.5542, AP: 0.7142
# Epoch 76
# Epoch: 076, AUC: 0.5278, AP: 0.7050
# Epoch 77
# Epoch: 077, AUC: 0.5215, AP: 0.7036
# Epoch 78
# Epoch: 078, AUC: 0.5193, AP: 0.7034
# Epoch 79
# Epoch: 079, AUC: 0.5178, AP: 0.7041
# Epoch 80
# Epoch: 080, AUC: 0.5182, AP: 0.7040
# Epoch 81
# Epoch: 081, AUC: 0.5191, AP: 0.7048
# Epoch 82
# Epoch: 082, AUC: 0.5177, AP: 0.7048
# Epoch 83
# Epoch: 083, AUC: 0.5146, AP: 0.7043
# Epoch 84
# Epoch: 084, AUC: 0.5128, AP: 0.7036
# Epoch 85
# Epoch: 085, AUC: 0.5124, AP: 0.7030
# Epoch 86
# Epoch: 086, AUC: 0.5124, AP: 0.7028
# Epoch 87
# Epoch: 087, AUC: 0.5119, AP: 0.7025
# Epoch 88
# Epoch: 088, AUC: 0.5113, AP: 0.7019
# Epoch 89
# Epoch: 089, AUC: 0.5109, AP: 0.7015
# Epoch 90
# Epoch: 090, AUC: 0.5110, AP: 0.7017
# Epoch 91
# Epoch: 091, AUC: 0.5107, AP: 0.7017
# Epoch 92
# Epoch: 092, AUC: 0.5114, AP: 0.7018
# Epoch 93
# Epoch: 093, AUC: 0.5113, AP: 0.7017
# Epoch 94
# Epoch: 094, AUC: 0.5108, AP: 0.7015
# Epoch 95
# Epoch: 095, AUC: 0.5114, AP: 0.7015
# Epoch 96
# Epoch: 096, AUC: 0.5110, AP: 0.7022
# Epoch 97
# Epoch: 097, AUC: 0.5124, AP: 0.7022
# Epoch 98
# Epoch: 098, AUC: 0.5119, AP: 0.7030
# Epoch 99
# Epoch: 099, AUC: 0.5148, AP: 0.7040
# Epoch 100
# Epoch: 100, AUC: 0.5151, AP: 0.7042
# Epoch 101
# Epoch: 101, AUC: 0.5135, AP: 0.7036
# Epoch 102
# Epoch: 102, AUC: 0.5123, AP: 0.7033
# Epoch 103
# Epoch: 103, AUC: 0.5118, AP: 0.7027
# Epoch 104
# Epoch: 104, AUC: 0.5105, AP: 0.7016
# Epoch 105
# Epoch: 105, AUC: 0.5118, AP: 0.7015
# Epoch 106
# Epoch: 106, AUC: 0.5121, AP: 0.7017
# Epoch 107
# Epoch: 107, AUC: 0.5120, AP: 0.7017
# Epoch 108
# Epoch: 108, AUC: 0.5111, AP: 0.7013
# Epoch 109
# Epoch: 109, AUC: 0.5100, AP: 0.7004
# Epoch 110
# Epoch: 110, AUC: 0.5102, AP: 0.7004
# Epoch 111
# Epoch: 111, AUC: 0.5094, AP: 0.7001
# Epoch 112
# Epoch: 112, AUC: 0.5091, AP: 0.6994
# Epoch 113
# Epoch: 113, AUC: 0.5090, AP: 0.6991
# Epoch 114
# Epoch: 114, AUC: 0.5090, AP: 0.6994
# Epoch 115
# Epoch: 115, AUC: 0.5100, AP: 0.7013
# Epoch 116
# Epoch: 116, AUC: 0.5121, AP: 0.7024
# Epoch 117
# Epoch: 117, AUC: 0.5127, AP: 0.7029
# Epoch 118
# Epoch: 118, AUC: 0.5128, AP: 0.7030
# Epoch 119
# Epoch: 119, AUC: 0.5112, AP: 0.7024
# Epoch 120
# Epoch: 120, AUC: 0.5113, AP: 0.7007
# Epoch 121
# Epoch: 121, AUC: 0.5100, AP: 0.6992
# Epoch 122
# Epoch: 122, AUC: 0.5110, AP: 0.7002
# Epoch 123
# Epoch: 123, AUC: 0.5112, AP: 0.7008
# Epoch 124
# Epoch: 124, AUC: 0.5119, AP: 0.7020
# Epoch 125
# Epoch: 125, AUC: 0.5113, AP: 0.7027
# Epoch 126
# Epoch: 126, AUC: 0.5120, AP: 0.7025
# Epoch 127
# Epoch: 127, AUC: 0.5119, AP: 0.7018
# Epoch 128
# Epoch: 128, AUC: 0.5103, AP: 0.7001
# Epoch 129
# Epoch: 129, AUC: 0.5077, AP: 0.6978
# Epoch 130
# Epoch: 130, AUC: 0.5071, AP: 0.6971
# Epoch 131
# Epoch: 131, AUC: 0.5076, AP: 0.6975
# Epoch 132
# Epoch: 132, AUC: 0.5106, AP: 0.7003
# Epoch 133
# Epoch: 133, AUC: 0.5119, AP: 0.7028
# Epoch 134
# Epoch: 134, AUC: 0.5127, AP: 0.7029
# Epoch 135
# Epoch: 135, AUC: 0.5126, AP: 0.7036
# Epoch 136
# Epoch: 136, AUC: 0.5128, AP: 0.7031
# Epoch 137
# Epoch: 137, AUC: 0.5121, AP: 0.7023
# Epoch 138
# Epoch: 138, AUC: 0.5105, AP: 0.7012
# Epoch 139
# Epoch: 139, AUC: 0.5095, AP: 0.6982
# Epoch 140
# Epoch: 140, AUC: 0.5066, AP: 0.6955
# Epoch 141
# Epoch: 141, AUC: 0.5071, AP: 0.6960
# Epoch 142
# Epoch: 142, AUC: 0.5086, AP: 0.6989
# Epoch 143
# Epoch: 143, AUC: 0.5115, AP: 0.7011
# Epoch 144
# Epoch: 144, AUC: 0.5127, AP: 0.7022
# Epoch 145
# Epoch: 145, AUC: 0.5138, AP: 0.7025
# Epoch 146
# Epoch: 146, AUC: 0.5131, AP: 0.7027
# Epoch 147
# Epoch: 147, AUC: 0.5131, AP: 0.7022
# Epoch 148
# Epoch: 148, AUC: 0.5142, AP: 0.7023
# Epoch 149
# Epoch: 149, AUC: 0.5148, AP: 0.7022
# Epoch 150
# Epoch: 150, AUC: 0.5168, AP: 0.7026
# Epoch 151
# Epoch: 151, AUC: 0.5165, AP: 0.7025
# Epoch 152
# Epoch: 152, AUC: 0.5145, AP: 0.7024
# Epoch 153
# Epoch: 153, AUC: 0.5124, AP: 0.7021
# Epoch 154
# Epoch: 154, AUC: 0.5129, AP: 0.7026
# Epoch 155
# Epoch: 155, AUC: 0.5135, AP: 0.7026
# Epoch 156
# Epoch: 156, AUC: 0.5120, AP: 0.7016
# Epoch 157
# Epoch: 157, AUC: 0.5103, AP: 0.7001
# Epoch 158
# Epoch: 158, AUC: 0.5141, AP: 0.7003
# Epoch 159
# Epoch: 159, AUC: 0.5118, AP: 0.6994
# Epoch 160
# Epoch: 160, AUC: 0.5094, AP: 0.6995
# Epoch 161
# Epoch: 161, AUC: 0.5114, AP: 0.7023
# Epoch 162
# Epoch: 162, AUC: 0.5124, AP: 0.7024
# Epoch 163
# Epoch: 163, AUC: 0.5126, AP: 0.7021
# Epoch 164
# Epoch: 164, AUC: 0.5114, AP: 0.7015
# Epoch 165
# Epoch: 165, AUC: 0.5114, AP: 0.7011
# Epoch 166
# Epoch: 166, AUC: 0.5124, AP: 0.7017
# Epoch 167
# Epoch: 167, AUC: 0.5134, AP: 0.7017
# Epoch 168
# Epoch: 168, AUC: 0.5144, AP: 0.7036
# Epoch 169
# Epoch: 169, AUC: 0.5131, AP: 0.7032
# Epoch 170
# Epoch: 170, AUC: 0.5126, AP: 0.7033
# Epoch 171
# Epoch: 171, AUC: 0.5123, AP: 0.7034
# Epoch 172
# Epoch: 172, AUC: 0.5131, AP: 0.7029
# Epoch 173
# Epoch: 173, AUC: 0.5130, AP: 0.7027
# Epoch 174
# Epoch: 174, AUC: 0.5124, AP: 0.7020
# Epoch 175
# Epoch: 175, AUC: 0.5108, AP: 0.7016
# Epoch 176
# Epoch: 176, AUC: 0.5109, AP: 0.7002
# Epoch 177
# Epoch: 177, AUC: 0.5107, AP: 0.6998
# Epoch 178
# Epoch: 178, AUC: 0.5112, AP: 0.7003
# Epoch 179
# Epoch: 179, AUC: 0.5113, AP: 0.7013
# Epoch 180
# Epoch: 180, AUC: 0.5128, AP: 0.7025
# Epoch 181
# Epoch: 181, AUC: 0.5121, AP: 0.7032
# Epoch 182
# Epoch: 182, AUC: 0.5130, AP: 0.7033
# Epoch 183
# Epoch: 183, AUC: 0.5137, AP: 0.7035
# Epoch 184
# Epoch: 184, AUC: 0.5151, AP: 0.7039
# Epoch 185
# Epoch: 185, AUC: 0.5181, AP: 0.7049
# Epoch 186
# Epoch: 186, AUC: 0.5149, AP: 0.7041
# Epoch 187
# Epoch: 187, AUC: 0.5121, AP: 0.7020
# Epoch 188
# Epoch: 188, AUC: 0.5121, AP: 0.7021
# Epoch 189
# Epoch: 189, AUC: 0.5133, AP: 0.7023
# Epoch 190
# Epoch: 190, AUC: 0.5120, AP: 0.7017
# Epoch 191
# Epoch: 191, AUC: 0.5112, AP: 0.7011
# Epoch 192
# Epoch: 192, AUC: 0.5115, AP: 0.7016
# Epoch 193
# Epoch: 193, AUC: 0.5138, AP: 0.7026
# Epoch 194
# Epoch: 194, AUC: 0.5162, AP: 0.7037
# Epoch 195
# Epoch: 195, AUC: 0.5177, AP: 0.7040
# Epoch 196
# Epoch: 196, AUC: 0.5176, AP: 0.7043
# Epoch 197
# Epoch: 197, AUC: 0.5156, AP: 0.7040
# Epoch 198
# Epoch: 198, AUC: 0.5142, AP: 0.7037
# Epoch 199
# Epoch: 199, AUC: 0.5130, AP: 0.7040
# Epoch 200
# Epoch: 200, AUC: 0.5136, AP: 0.7034
# Epoch 201
# Epoch: 201, AUC: 0.5128, AP: 0.7023
# Epoch 202
# Epoch: 202, AUC: 0.5105, AP: 0.7016
# Epoch 203
# Epoch: 203, AUC: 0.5117, AP: 0.7026
# Epoch 204
# Epoch: 204, AUC: 0.5130, AP: 0.7042
# Epoch 205
# Epoch: 205, AUC: 0.5141, AP: 0.7040
# Epoch 206
# Epoch: 206, AUC: 0.5140, AP: 0.7039
# Epoch 207
# Epoch: 207, AUC: 0.5119, AP: 0.7030
# Epoch 208
# Epoch: 208, AUC: 0.5104, AP: 0.7010
# Epoch 209
# Epoch: 209, AUC: 0.5079, AP: 0.6992
# Epoch 210
# Epoch: 210, AUC: 0.5089, AP: 0.6988
# Epoch 211
# Epoch: 211, AUC: 0.5089, AP: 0.6992
# Epoch 212
# Epoch: 212, AUC: 0.5100, AP: 0.7011
# Epoch 213
# Epoch: 213, AUC: 0.5112, AP: 0.7017
# Epoch 214
# Epoch: 214, AUC: 0.5120, AP: 0.7025
# Epoch 215
# Epoch: 215, AUC: 0.5130, AP: 0.7029
# Epoch 216
# Epoch: 216, AUC: 0.5138, AP: 0.7039
# Epoch 217
# Epoch: 217, AUC: 0.5154, AP: 0.7049
# Epoch 218
# Epoch: 218, AUC: 0.5150, AP: 0.7051
# Epoch 219
# Epoch: 219, AUC: 0.5167, AP: 0.7053
# Epoch 220
# Epoch: 220, AUC: 0.5169, AP: 0.7051
# Epoch 221
# Epoch: 221, AUC: 0.5156, AP: 0.7046
# Epoch 222
# Epoch: 222, AUC: 0.5138, AP: 0.7042
# Epoch 223
# Epoch: 223, AUC: 0.5127, AP: 0.7028
# Epoch 224
# Epoch: 224, AUC: 0.5117, AP: 0.7019
# Epoch 225
# Epoch: 225, AUC: 0.5102, AP: 0.7015
# Epoch 226
# Epoch: 226, AUC: 0.5104, AP: 0.7017
# Epoch 227
# Epoch: 227, AUC: 0.5116, AP: 0.7016
# Epoch 228
# Epoch: 228, AUC: 0.5118, AP: 0.7019
# Epoch 229
# Epoch: 229, AUC: 0.5122, AP: 0.7020
# Epoch 230
# Epoch: 230, AUC: 0.5138, AP: 0.7028
# Epoch 231
# Epoch: 231, AUC: 0.5150, AP: 0.7033
# Epoch 232
# Epoch: 232, AUC: 0.5159, AP: 0.7035
# Epoch 233
# Epoch: 233, AUC: 0.5159, AP: 0.7035
# Epoch 234
# Epoch: 234, AUC: 0.5136, AP: 0.7034
# Epoch 235
# Epoch: 235, AUC: 0.5133, AP: 0.7029
# Epoch 236
# Epoch: 236, AUC: 0.5126, AP: 0.7029
# Epoch 237
# Epoch: 237, AUC: 0.5126, AP: 0.7029
# Epoch 238
# Epoch: 238, AUC: 0.5127, AP: 0.7029
# Epoch 239
# Epoch: 239, AUC: 0.5127, AP: 0.7027
# Epoch 240
# Epoch: 240, AUC: 0.5119, AP: 0.7021
# Epoch 241
# Epoch: 241, AUC: 0.5106, AP: 0.7015
# Epoch 242
# Epoch: 242, AUC: 0.5119, AP: 0.7010
# Epoch 243
# Epoch: 243, AUC: 0.5120, AP: 0.7015
# Epoch 244
# Epoch: 244, AUC: 0.5116, AP: 0.7028
# Epoch 245
# Epoch: 245, AUC: 0.5126, AP: 0.7029
# Epoch 246
# Epoch: 246, AUC: 0.5129, AP: 0.7030
# Epoch 247
# Epoch: 247, AUC: 0.5130, AP: 0.7031
# Epoch 248
# Epoch: 248, AUC: 0.5116, AP: 0.7030
# Epoch 249
# Epoch: 249, AUC: 0.5119, AP: 0.7021
# Epoch 250
# Epoch: 250, AUC: 0.5150, AP: 0.7032
# Epoch 251
# Epoch: 251, AUC: 0.5160, AP: 0.7037
# Epoch 252
# Epoch: 252, AUC: 0.5146, AP: 0.7031
# Epoch 253
# Epoch: 253, AUC: 0.5138, AP: 0.7032
# Epoch 254
# Epoch: 254, AUC: 0.5134, AP: 0.7034
# Epoch 255
# Epoch: 255, AUC: 0.5135, AP: 0.7037
# Epoch 256
# Epoch: 256, AUC: 0.5142, AP: 0.7042
# Epoch 257
# Epoch: 257, AUC: 0.5141, AP: 0.7041
# Epoch 258
# Epoch: 258, AUC: 0.5134, AP: 0.7037
# Epoch 259
# Epoch: 259, AUC: 0.5121, AP: 0.7022
# Epoch 260
# Epoch: 260, AUC: 0.5096, AP: 0.6999
# Epoch 261
# Epoch: 261, AUC: 0.5083, AP: 0.6986
# Epoch 262
# Epoch: 262, AUC: 0.5084, AP: 0.6987
# Epoch 263
# Epoch: 263, AUC: 0.5089, AP: 0.6996
# Epoch 264
# Epoch: 264, AUC: 0.5114, AP: 0.7013
# Epoch 265
# Epoch: 265, AUC: 0.5125, AP: 0.7029
# Epoch 266
# Epoch: 266, AUC: 0.5130, AP: 0.7034
# Epoch 267
# Epoch: 267, AUC: 0.5136, AP: 0.7036
# Epoch 268
# Epoch: 268, AUC: 0.5130, AP: 0.7040
# Epoch 269
# Epoch: 269, AUC: 0.5140, AP: 0.7035
# Epoch 270
# Epoch: 270, AUC: 0.5144, AP: 0.7036
# Epoch 271
# Epoch: 271, AUC: 0.5138, AP: 0.7041
# Epoch 272
# Epoch: 272, AUC: 0.5141, AP: 0.7035
# Epoch 273
# Epoch: 273, AUC: 0.5135, AP: 0.7033
# Epoch 274
# Epoch: 274, AUC: 0.5130, AP: 0.7030
# Epoch 275
# Epoch: 275, AUC: 0.5129, AP: 0.7031
# Epoch 276
# Epoch: 276, AUC: 0.5121, AP: 0.7030
# Epoch 277
# Epoch: 277, AUC: 0.5120, AP: 0.7029
# Epoch 278
# Epoch: 278, AUC: 0.5119, AP: 0.7026
# Epoch 279
# Epoch: 279, AUC: 0.5117, AP: 0.7018
# Epoch 280
# Epoch: 280, AUC: 0.5104, AP: 0.7007
# Epoch 281
# Epoch: 281, AUC: 0.5096, AP: 0.6998
# Epoch 282
# Epoch: 282, AUC: 0.5098, AP: 0.7000
# Epoch 283
# Epoch: 283, AUC: 0.5117, AP: 0.7016
# Epoch 284
# Epoch: 284, AUC: 0.5135, AP: 0.7032
# Epoch 285
# Epoch: 285, AUC: 0.5147, AP: 0.7046
# Epoch 286
# Epoch: 286, AUC: 0.5165, AP: 0.7047
# Epoch 287
# Epoch: 287, AUC: 0.5166, AP: 0.7046
# Epoch 288
# Epoch: 288, AUC: 0.5160, AP: 0.7043
# Epoch 289
# Epoch: 289, AUC: 0.5153, AP: 0.7038
# Epoch 290
# Epoch: 290, AUC: 0.5133, AP: 0.7029
# Epoch 291
# Epoch: 291, AUC: 0.5122, AP: 0.7022
# Epoch 292
# Epoch: 292, AUC: 0.5121, AP: 0.7021
# Epoch 293
# Epoch: 293, AUC: 0.5113, AP: 0.7026
# Epoch 294
# Epoch: 294, AUC: 0.5124, AP: 0.7024
# Epoch 295
# Epoch: 295, AUC: 0.5119, AP: 0.7034
# Epoch 296
# Epoch: 296, AUC: 0.5126, AP: 0.7029
# Epoch 297
# Epoch: 297, AUC: 0.5131, AP: 0.7031
# Epoch 298
# Epoch: 298, AUC: 0.5147, AP: 0.7037
# Epoch 299
# Epoch: 299, AUC: 0.5143, AP: 0.7041
# Epoch 300
# Epoch: 300, AUC: 0.5158, AP: 0.7037
# Epoch 301
# Epoch: 301, AUC: 0.5163, AP: 0.7042
# Epoch 302
# Epoch: 302, AUC: 0.5182, AP: 0.7058
# Epoch 303
# Epoch: 303, AUC: 0.5196, AP: 0.7066
# Epoch 304
# Epoch: 304, AUC: 0.5179, AP: 0.7052
# Epoch 305
# Epoch: 305, AUC: 0.5162, AP: 0.7045
# Epoch 306
# Epoch: 306, AUC: 0.5134, AP: 0.7023
# Epoch 307
# Epoch: 307, AUC: 0.5113, AP: 0.7005
# Epoch 308
# Epoch: 308, AUC: 0.5092, AP: 0.6990
# Epoch 309
# Epoch: 309, AUC: 0.5080, AP: 0.6984
# Epoch 310
# Epoch: 310, AUC: 0.5087, AP: 0.6988
# Epoch 311
# Epoch: 311, AUC: 0.5109, AP: 0.7005
# Epoch 312
# Epoch: 312, AUC: 0.5115, AP: 0.7024
# Epoch 313
# Epoch: 313, AUC: 0.5128, AP: 0.7030
# Epoch 314
# Epoch: 314, AUC: 0.5139, AP: 0.7045
# Epoch 315
# Epoch: 315, AUC: 0.5202, AP: 0.7061
# Epoch 316
# Epoch: 316, AUC: 0.5211, AP: 0.7065
# Epoch 317
# Epoch: 317, AUC: 0.5200, AP: 0.7055
# Epoch 318
# Epoch: 318, AUC: 0.5185, AP: 0.7046
# Epoch 319
# Epoch: 319, AUC: 0.5159, AP: 0.7045
# Epoch 320
# Epoch: 320, AUC: 0.5130, AP: 0.7025
# Epoch 321
# Epoch: 321, AUC: 0.5118, AP: 0.7020
# Epoch 322
# Epoch: 322, AUC: 0.5117, AP: 0.7019
# Epoch 323
# Epoch: 323, AUC: 0.5113, AP: 0.7014
# Epoch 324
# Epoch: 324, AUC: 0.5118, AP: 0.7019
# Epoch 325
# Epoch: 325, AUC: 0.5113, AP: 0.7021
# Epoch 326
# Epoch: 326, AUC: 0.5123, AP: 0.7025
# Epoch 327
# Epoch: 327, AUC: 0.5146, AP: 0.7032
# Epoch 328
# Epoch: 328, AUC: 0.5153, AP: 0.7034
# Epoch 329
# Epoch: 329, AUC: 0.5154, AP: 0.7035
# Epoch 330
# Epoch: 330, AUC: 0.5155, AP: 0.7035
# Epoch 331
# Epoch: 331, AUC: 0.5145, AP: 0.7039
# Epoch 332
# Epoch: 332, AUC: 0.5146, AP: 0.7032
# Epoch 333
# Epoch: 333, AUC: 0.5138, AP: 0.7032
# Epoch 334
# Epoch: 334, AUC: 0.5122, AP: 0.7029
# Epoch 335
# Epoch: 335, AUC: 0.5122, AP: 0.7035
# Epoch 336
# Epoch: 336, AUC: 0.5126, AP: 0.7030
# Epoch 337
# Epoch: 337, AUC: 0.5117, AP: 0.7032
# Epoch 338
# Epoch: 338, AUC: 0.5132, AP: 0.7027
# Epoch 339
# Epoch: 339, AUC: 0.5155, AP: 0.7036
# Epoch 340
# Epoch: 340, AUC: 0.5160, AP: 0.7038
# Epoch 341
# Epoch: 341, AUC: 0.5157, AP: 0.7038
# Epoch 342
# Epoch: 342, AUC: 0.5134, AP: 0.7034
# Epoch 343
# Epoch: 343, AUC: 0.5132, AP: 0.7034
# Epoch 344
# Epoch: 344, AUC: 0.5124, AP: 0.7039
# Epoch 345
# Epoch: 345, AUC: 0.5132, AP: 0.7038
# Epoch 346
# Epoch: 346, AUC: 0.5132, AP: 0.7044
# Epoch 347
# Epoch: 347, AUC: 0.5140, AP: 0.7039
# Epoch 348
# Epoch: 348, AUC: 0.5139, AP: 0.7036
# Epoch 349
# Epoch: 349, AUC: 0.5128, AP: 0.7038
# Epoch 350
# Epoch: 350, AUC: 0.5135, AP: 0.7034
# Epoch 351
# Epoch: 351, AUC: 0.5137, AP: 0.7035
# Epoch 352
# Epoch: 352, AUC: 0.5139, AP: 0.7037
# Epoch 353
# Epoch: 353, AUC: 0.5137, AP: 0.7040
# Epoch 354
# Epoch: 354, AUC: 0.5160, AP: 0.7047
# Epoch 355
# Epoch: 355, AUC: 0.5169, AP: 0.7049
# Epoch 356
# Epoch: 356, AUC: 0.5170, AP: 0.7056
# Epoch 357
# Epoch: 357, AUC: 0.5178, AP: 0.7051
# Epoch 358
# Epoch: 358, AUC: 0.5151, AP: 0.7047
# Epoch 359
# Epoch: 359, AUC: 0.5125, AP: 0.7024
# Epoch 360
# Epoch: 360, AUC: 0.5106, AP: 0.7009
# Epoch 361
# Epoch: 361, AUC: 0.5102, AP: 0.7002
# Epoch 362
# Epoch: 362, AUC: 0.5100, AP: 0.7011
# Epoch 363
# Epoch: 363, AUC: 0.5125, AP: 0.7023
# Epoch 364
# Epoch: 364, AUC: 0.5126, AP: 0.7030
# Epoch 365
# Epoch: 365, AUC: 0.5124, AP: 0.7038
# Epoch 366
# Epoch: 366, AUC: 0.5130, AP: 0.7044
# Epoch 367
# Epoch: 367, AUC: 0.5149, AP: 0.7046
# Epoch 368
# Epoch: 368, AUC: 0.5147, AP: 0.7047
# Epoch 369
# Epoch: 369, AUC: 0.5147, AP: 0.7043
# Epoch 370
# Epoch: 370, AUC: 0.5140, AP: 0.7037
# Epoch 371
# Epoch: 371, AUC: 0.5138, AP: 0.7034
# Epoch 372
# Epoch: 372, AUC: 0.5136, AP: 0.7032
# Epoch 373
# Epoch: 373, AUC: 0.5127, AP: 0.7030
# Epoch 374
# Epoch: 374, AUC: 0.5130, AP: 0.7031
# Epoch 375
# Epoch: 375, AUC: 0.5131, AP: 0.7034
# Epoch 376
# Epoch: 376, AUC: 0.5124, AP: 0.7039
# Epoch 377
# Epoch: 377, AUC: 0.5159, AP: 0.7044
# Epoch 378
# Epoch: 378, AUC: 0.5169, AP: 0.7042
# Epoch 379
# Epoch: 379, AUC: 0.5165, AP: 0.7037
# Epoch 380
# Epoch: 380, AUC: 0.5146, AP: 0.7027
# Epoch 381
# Epoch: 381, AUC: 0.5115, AP: 0.7013
# Epoch 382
# Epoch: 382, AUC: 0.5099, AP: 0.7008
# Epoch 383
# Epoch: 383, AUC: 0.5108, AP: 0.7012
# Epoch 384
# Epoch: 384, AUC: 0.5114, AP: 0.7015
# Epoch 385
# Epoch: 385, AUC: 0.5115, AP: 0.7017
# Epoch 386
# Epoch: 386, AUC: 0.5119, AP: 0.7019
# Epoch 387
# Epoch: 387, AUC: 0.5127, AP: 0.7024
# Epoch 388
# Epoch: 388, AUC: 0.5149, AP: 0.7038
# Epoch 389
# Epoch: 389, AUC: 0.5156, AP: 0.7043
# Epoch 390
# Epoch: 390, AUC: 0.5160, AP: 0.7046
# Epoch 391
# Epoch: 391, AUC: 0.5162, AP: 0.7047
# Epoch 392
# Epoch: 392, AUC: 0.5152, AP: 0.7051
# Epoch 393
# Epoch: 393, AUC: 0.5155, AP: 0.7048
# Epoch 394
# Epoch: 394, AUC: 0.5147, AP: 0.7050
# Epoch 395
# Epoch: 395, AUC: 0.5142, AP: 0.7041
# Epoch 396
# Epoch: 396, AUC: 0.5136, AP: 0.7038
# Epoch 397
# Epoch: 397, AUC: 0.5123, AP: 0.7039
# Epoch 398
# Epoch: 398, AUC: 0.5123, AP: 0.7032
# Epoch 399
# Epoch: 399, AUC: 0.5120, AP: 0.7027
# Epoch 400
# Epoch: 400, AUC: 0.5110, AP: 0.7023
# Epoch 401
# Epoch: 401, AUC: 0.5126, AP: 0.7022
# Epoch 402
# Epoch: 402, AUC: 0.5152, AP: 0.7033
# Epoch 403
# Epoch: 403, AUC: 0.5169, AP: 0.7047
# Epoch 404
# Epoch: 404, AUC: 0.5158, AP: 0.7051
# Epoch 405
# Epoch: 405, AUC: 0.5158, AP: 0.7044
# Epoch 406
# Epoch: 406, AUC: 0.5143, AP: 0.7041
# Epoch 407
# Epoch: 407, AUC: 0.5137, AP: 0.7035
# Epoch 408
# Epoch: 408, AUC: 0.5126, AP: 0.7025
# Epoch 409
# Epoch: 409, AUC: 0.5112, AP: 0.7024
# Epoch 410
# Epoch: 410, AUC: 0.5110, AP: 0.7013
# Epoch 411
# Epoch: 411, AUC: 0.5103, AP: 0.7002
# Epoch 412
# Epoch: 412, AUC: 0.5081, AP: 0.6994
# Epoch 413
# Epoch: 413, AUC: 0.5085, AP: 0.6987
# Epoch 414
# Epoch: 414, AUC: 0.5102, AP: 0.7001
# Epoch 415
# Epoch: 415, AUC: 0.5114, AP: 0.7015
# Epoch 416
# Epoch: 416, AUC: 0.5118, AP: 0.7024
# Epoch 417
# Epoch: 417, AUC: 0.5151, AP: 0.7037
# Epoch 418
# Epoch: 418, AUC: 0.5168, AP: 0.7047
# Epoch 419
# Epoch: 419, AUC: 0.5172, AP: 0.7060
# Epoch 420
# Epoch: 420, AUC: 0.5177, AP: 0.7056
# Epoch 421
# Epoch: 421, AUC: 0.5169, AP: 0.7055
# Epoch 422
# Epoch: 422, AUC: 0.5148, AP: 0.7044
# Epoch 423
# Epoch: 423, AUC: 0.5141, AP: 0.7039
# Epoch 424
# Epoch: 424, AUC: 0.5153, AP: 0.7041
# Epoch 425
# Epoch: 425, AUC: 0.5143, AP: 0.7040
# Epoch 426
# Epoch: 426, AUC: 0.5142, AP: 0.7030
# Epoch 427
# Epoch: 427, AUC: 0.5139, AP: 0.7029
# Epoch 428
# Epoch: 428, AUC: 0.5122, AP: 0.7034
# Epoch 429
# Epoch: 429, AUC: 0.5131, AP: 0.7033
# Epoch 430
# Epoch: 430, AUC: 0.5129, AP: 0.7037
# Epoch 431
# Epoch: 431, AUC: 0.5139, AP: 0.7041
# Epoch 432
# Epoch: 432, AUC: 0.5143, AP: 0.7041
# Epoch 433
# Epoch: 433, AUC: 0.5151, AP: 0.7043
# Epoch 434
# Epoch: 434, AUC: 0.5154, AP: 0.7045
# Epoch 435
# Epoch: 435, AUC: 0.5145, AP: 0.7040
# Epoch 436
# Epoch: 436, AUC: 0.5138, AP: 0.7038
# Epoch 437
# Epoch: 437, AUC: 0.5134, AP: 0.7036
# Epoch 438
# Epoch: 438, AUC: 0.5128, AP: 0.7030
# Epoch 439
# Epoch: 439, AUC: 0.5118, AP: 0.7024
# Epoch 440
# Epoch: 440, AUC: 0.5124, AP: 0.7025
# Epoch 441
# Epoch: 441, AUC: 0.5126, AP: 0.7025
# Epoch 442
# Epoch: 442, AUC: 0.5121, AP: 0.7031
# Epoch 443
# Epoch: 443, AUC: 0.5131, AP: 0.7037
# Epoch 444
# Epoch: 444, AUC: 0.5134, AP: 0.7036
# Epoch 445
# Epoch: 445, AUC: 0.5126, AP: 0.7040
# Epoch 446
# Epoch: 446, AUC: 0.5141, AP: 0.7041
# Epoch 447
# Epoch: 447, AUC: 0.5142, AP: 0.7041
# Epoch 448
# Epoch: 448, AUC: 0.5145, AP: 0.7041
# Epoch 449
# Epoch: 449, AUC: 0.5137, AP: 0.7040
# Epoch 450
# Epoch: 450, AUC: 0.5139, AP: 0.7042
# Epoch 451
# Epoch: 451, AUC: 0.5144, AP: 0.7042
# Epoch 452
# Epoch: 452, AUC: 0.5134, AP: 0.7036
# Epoch 453
# Epoch: 453, AUC: 0.5134, AP: 0.7034
# Epoch 454
# Epoch: 454, AUC: 0.5127, AP: 0.7032
# Epoch 455
# Epoch: 455, AUC: 0.5143, AP: 0.7045
# Epoch 456
# Epoch: 456, AUC: 0.5159, AP: 0.7046
# Epoch 457
# Epoch: 457, AUC: 0.5165, AP: 0.7050
# Epoch 458
# Epoch: 458, AUC: 0.5155, AP: 0.7049
# Epoch 459
# Epoch: 459, AUC: 0.5152, AP: 0.7044
# Epoch 460
# Epoch: 460, AUC: 0.5123, AP: 0.7023
# Epoch 461
# Epoch: 461, AUC: 0.5102, AP: 0.7008
# Epoch 462
# Epoch: 462, AUC: 0.5097, AP: 0.7000
# Epoch 463
# Epoch: 463, AUC: 0.5099, AP: 0.7002
# Epoch 464
# Epoch: 464, AUC: 0.5113, AP: 0.7014
# Epoch 465
# Epoch: 465, AUC: 0.5118, AP: 0.7026
# Epoch 466
# Epoch: 466, AUC: 0.5132, AP: 0.7036
# Epoch 467
# Epoch: 467, AUC: 0.5131, AP: 0.7045
# Epoch 468
# Epoch: 468, AUC: 0.5162, AP: 0.7051
# Epoch 469
# Epoch: 469, AUC: 0.5170, AP: 0.7058
# Epoch 470
# Epoch: 470, AUC: 0.5170, AP: 0.7048
# Epoch 471
# Epoch: 471, AUC: 0.5145, AP: 0.7036
# Epoch 472
# Epoch: 472, AUC: 0.5138, AP: 0.7036
# Epoch 473
# Epoch: 473, AUC: 0.5137, AP: 0.7037
# Epoch 474
# Epoch: 474, AUC: 0.5139, AP: 0.7037
# Epoch 475
# Epoch: 475, AUC: 0.5139, AP: 0.7037
# Epoch 476
# Epoch: 476, AUC: 0.5138, AP: 0.7038
# Epoch 477
# Epoch: 477, AUC: 0.5139, AP: 0.7036
# Epoch 478
# Epoch: 478, AUC: 0.5132, AP: 0.7031
# Epoch 479
# Epoch: 479, AUC: 0.5139, AP: 0.7034
# Epoch 480
# Epoch: 480, AUC: 0.5136, AP: 0.7031
# Epoch 481
# Epoch: 481, AUC: 0.5137, AP: 0.7033
# Epoch 482
# Epoch: 482, AUC: 0.5126, AP: 0.7027
# Epoch 483
# Epoch: 483, AUC: 0.5123, AP: 0.7022
# Epoch 484
# Epoch: 484, AUC: 0.5124, AP: 0.7022
# Epoch 485
# Epoch: 485, AUC: 0.5127, AP: 0.7029
# Epoch 486
# Epoch: 486, AUC: 0.5144, AP: 0.7040
# Epoch 487
# Epoch: 487, AUC: 0.5138, AP: 0.7040
# Epoch 488
# Epoch: 488, AUC: 0.5144, AP: 0.7048
# Epoch 489
# Epoch: 489, AUC: 0.5180, AP: 0.7054
# Epoch 490
# Epoch: 490, AUC: 0.5174, AP: 0.7053
# Epoch 491
# Epoch: 491, AUC: 0.5162, AP: 0.7049
# Epoch 492
# Epoch: 492, AUC: 0.5150, AP: 0.7045
# Epoch 493
# Epoch: 493, AUC: 0.5152, AP: 0.7047
# Epoch 494
# Epoch: 494, AUC: 0.5155, AP: 0.7048
# Epoch 495
# Epoch: 495, AUC: 0.5141, AP: 0.7048
# Epoch 496
# Epoch: 496, AUC: 0.5131, AP: 0.7042
# Epoch 497
# Epoch: 497, AUC: 0.5133, AP: 0.7033
# Epoch 498
# Epoch: 498, AUC: 0.5129, AP: 0.7031
# Epoch 499
# Epoch: 499, AUC: 0.5132, AP: 0.7033
# Epoch 500
# Epoch: 500, AUC: 0.5139, AP: 0.7038
# Epoch 501
# Epoch: 501, AUC: 0.5137, AP: 0.7047
# Epoch 502
# Epoch: 502, AUC: 0.5158, AP: 0.7051
# Epoch 503
# Epoch: 503, AUC: 0.5164, AP: 0.7056
# Epoch 504
# Epoch: 504, AUC: 0.5153, AP: 0.7050
# Epoch 505
# Epoch: 505, AUC: 0.5135, AP: 0.7045
# Epoch 506
# Epoch: 506, AUC: 0.5121, AP: 0.7033
# Epoch 507
# Epoch: 507, AUC: 0.5112, AP: 0.7013
# Epoch 508
# Epoch: 508, AUC: 0.5106, AP: 0.7008
# Epoch 509
# Epoch: 509, AUC: 0.5108, AP: 0.7012
# Epoch 510
# Epoch: 510, AUC: 0.5127, AP: 0.7030
# Epoch 511
# Epoch: 511, AUC: 0.5154, AP: 0.7047
# Epoch 512
# Epoch: 512, AUC: 0.5178, AP: 0.7059
# Epoch 513
# Epoch: 513, AUC: 0.5203, AP: 0.7077
# Epoch 514
# Epoch: 514, AUC: 0.5195, AP: 0.7070
# Epoch 515
# Epoch: 515, AUC: 0.5179, AP: 0.7062
# Epoch 516
# Epoch: 516, AUC: 0.5164, AP: 0.7053
# Epoch 517
# Epoch: 517, AUC: 0.5147, AP: 0.7046
# Epoch 518
# Epoch: 518, AUC: 0.5146, AP: 0.7043
# Epoch 519
# Epoch: 519, AUC: 0.5146, AP: 0.7041
# Epoch 520
# Epoch: 520, AUC: 0.5126, AP: 0.7040
# Epoch 521
# Epoch: 521, AUC: 0.5126, AP: 0.7033
# Epoch 522
# Epoch: 522, AUC: 0.5127, AP: 0.7035
# Epoch 523
# Epoch: 523, AUC: 0.5152, AP: 0.7048
# Epoch 524
# Epoch: 524, AUC: 0.5178, AP: 0.7070
# Epoch 525
# Epoch: 525, AUC: 0.5183, AP: 0.7073
# Epoch 526
# Epoch: 526, AUC: 0.5186, AP: 0.7072
# Epoch 527
# Epoch: 527, AUC: 0.5161, AP: 0.7051
# Epoch 528
# Epoch: 528, AUC: 0.5159, AP: 0.7038
# Epoch 529
# Epoch: 529, AUC: 0.5148, AP: 0.7033
# Epoch 530
# Epoch: 530, AUC: 0.5129, AP: 0.7028
# Epoch 531
# Epoch: 531, AUC: 0.5132, AP: 0.7036
# Epoch 532
# Epoch: 532, AUC: 0.5137, AP: 0.7040
# Epoch 533
# Epoch: 533, AUC: 0.5137, AP: 0.7041
# Epoch 534
# Epoch: 534, AUC: 0.5135, AP: 0.7041
# Epoch 535
# Epoch: 535, AUC: 0.5142, AP: 0.7044
# Epoch 536
# Epoch: 536, AUC: 0.5168, AP: 0.7060
# Epoch 537
# Epoch: 537, AUC: 0.5189, AP: 0.7079
# Epoch 538
# Epoch: 538, AUC: 0.5188, AP: 0.7077
# Epoch 539
# Epoch: 539, AUC: 0.5159, AP: 0.7044
# Epoch 540
# Epoch: 540, AUC: 0.5151, AP: 0.7046
# Epoch 541
# Epoch: 541, AUC: 0.5149, AP: 0.7043
# Epoch 542
# Epoch: 542, AUC: 0.5149, AP: 0.7043
# Epoch 543
# Epoch: 543, AUC: 0.5145, AP: 0.7041
# Epoch 544
# Epoch: 544, AUC: 0.5135, AP: 0.7038
# Epoch 545
# Epoch: 545, AUC: 0.5130, AP: 0.7039
# Epoch 546
# Epoch: 546, AUC: 0.5159, AP: 0.7051
# Epoch 547
# Epoch: 547, AUC: 0.5180, AP: 0.7058
# Epoch 548
# Epoch: 548, AUC: 0.5182, AP: 0.7058
# Epoch 549
# Epoch: 549, AUC: 0.5178, AP: 0.7053
# Epoch 550
# Epoch: 550, AUC: 0.5161, AP: 0.7041
# Epoch 551
# Epoch: 551, AUC: 0.5140, AP: 0.7028
# Epoch 552
# Epoch: 552, AUC: 0.5126, AP: 0.7015
# Epoch 553
# Epoch: 553, AUC: 0.5126, AP: 0.7016
# Epoch 554
# Epoch: 554, AUC: 0.5124, AP: 0.7019
# Epoch 555
# Epoch: 555, AUC: 0.5120, AP: 0.7023
# Epoch 556
# Epoch: 556, AUC: 0.5130, AP: 0.7032
# Epoch 557
# Epoch: 557, AUC: 0.5147, AP: 0.7041
# Epoch 558
# Epoch: 558, AUC: 0.5156, AP: 0.7046
# Epoch 559
# Epoch: 559, AUC: 0.5171, AP: 0.7071
# Epoch 560
# Epoch: 560, AUC: 0.5154, AP: 0.7048
# Epoch 561
# Epoch: 561, AUC: 0.5131, AP: 0.7047
# Epoch 562
# Epoch: 562, AUC: 0.5148, AP: 0.7048
# Epoch 563
# Epoch: 563, AUC: 0.5151, AP: 0.7050
# Epoch 564
# Epoch: 564, AUC: 0.5139, AP: 0.7046
# Epoch 565
# Epoch: 565, AUC: 0.5152, AP: 0.7046
# Epoch 566
# Epoch: 566, AUC: 0.5163, AP: 0.7043
# Epoch 567
# Epoch: 567, AUC: 0.5153, AP: 0.7035
# Epoch 568
# Epoch: 568, AUC: 0.5151, AP: 0.7039
# Epoch 569
# Epoch: 569, AUC: 0.5146, AP: 0.7043
# Epoch 570
# Epoch: 570, AUC: 0.5146, AP: 0.7046
# Epoch 571
# Epoch: 571, AUC: 0.5160, AP: 0.7056
# Epoch 572
# Epoch: 572, AUC: 0.5158, AP: 0.7058
# Epoch 573
# Epoch: 573, AUC: 0.5173, AP: 0.7062
# Epoch 574
# Epoch: 574, AUC: 0.5167, AP: 0.7053
# Epoch 575
# Epoch: 575, AUC: 0.5164, AP: 0.7047
# Epoch 576
# Epoch: 576, AUC: 0.5153, AP: 0.7036
# Epoch 577
# Epoch: 577, AUC: 0.5130, AP: 0.7023
# Epoch 578
# Epoch: 578, AUC: 0.5123, AP: 0.7022
# Epoch 579
# Epoch: 579, AUC: 0.5127, AP: 0.7027
# Epoch 580
# Epoch: 580, AUC: 0.5141, AP: 0.7038
# Epoch 581
# Epoch: 581, AUC: 0.5147, AP: 0.7041
# Epoch 582
# Epoch: 582, AUC: 0.5138, AP: 0.7038
# Epoch 583
# Epoch: 583, AUC: 0.5157, AP: 0.7043
# Epoch 584
# Epoch: 584, AUC: 0.5170, AP: 0.7042
# Epoch 585
# Epoch: 585, AUC: 0.5178, AP: 0.7062
# Epoch 586
# Epoch: 586, AUC: 0.5155, AP: 0.7024
# Epoch 587
# Epoch: 587, AUC: 0.5171, AP: 0.7036
# Epoch 588
# Epoch: 588, AUC: 0.5178, AP: 0.7049
# Epoch 589
# Epoch: 589, AUC: 0.5153, AP: 0.7048
# Epoch 590
# Epoch: 590, AUC: 0.5142, AP: 0.7052
# Epoch 591
# Epoch: 591, AUC: 0.5142, AP: 0.7046
# Epoch 592
# Epoch: 592, AUC: 0.5137, AP: 0.7041
# Epoch 593
# Epoch: 593, AUC: 0.5134, AP: 0.7039
# Epoch 594
# Epoch: 594, AUC: 0.5143, AP: 0.7042
# Epoch 595
# Epoch: 595, AUC: 0.5157, AP: 0.7048
# Epoch 596
# Epoch: 596, AUC: 0.5151, AP: 0.7045
# Epoch 597
# Epoch: 597, AUC: 0.5142, AP: 0.7041
# Epoch 598
# Epoch: 598, AUC: 0.5142, AP: 0.7043
# Epoch 599
# Epoch: 599, AUC: 0.5142, AP: 0.7042
# Epoch 600
# Epoch: 600, AUC: 0.5151, AP: 0.7059
# Epoch 601
# Epoch: 601, AUC: 0.5139, AP: 0.7036
# Epoch 602
# Epoch: 602, AUC: 0.5146, AP: 0.7037
# Epoch 603
# Epoch: 603, AUC: 0.5154, AP: 0.7037
# Epoch 604
# Epoch: 604, AUC: 0.5154, AP: 0.7033
# Epoch 605
# Epoch: 605, AUC: 0.5145, AP: 0.7026
# Epoch 606
# Epoch: 606, AUC: 0.5132, AP: 0.7018
# Epoch 607
# Epoch: 607, AUC: 0.5125, AP: 0.7018
# Epoch 608
# Epoch: 608, AUC: 0.5133, AP: 0.7040
# Epoch 609
# Epoch: 609, AUC: 0.5115, AP: 0.7027
# Epoch 610
# Epoch: 610, AUC: 0.5128, AP: 0.7029
# Epoch 611
# Epoch: 611, AUC: 0.5126, AP: 0.7034
# Epoch 612
# Epoch: 612, AUC: 0.5121, AP: 0.7037
# Epoch 613
# Epoch: 613, AUC: 0.5130, AP: 0.7034
# Epoch 614
# Epoch: 614, AUC: 0.5125, AP: 0.7030
# Epoch 615
# Epoch: 615, AUC: 0.5123, AP: 0.7029
# Epoch 616
# Epoch: 616, AUC: 0.5129, AP: 0.7032
# Epoch 617
# Epoch: 617, AUC: 0.5132, AP: 0.7036
# Epoch 618
# Epoch: 618, AUC: 0.5130, AP: 0.7037
# Epoch 619
# Epoch: 619, AUC: 0.5132, AP: 0.7037
# Epoch 620
# Epoch: 620, AUC: 0.5131, AP: 0.7037
# Epoch 621
# Epoch: 621, AUC: 0.5131, AP: 0.7036
# Epoch 622
# Epoch: 622, AUC: 0.5121, AP: 0.7040
# Epoch 623
# Epoch: 623, AUC: 0.5160, AP: 0.7050
# Epoch 624
# Epoch: 624, AUC: 0.5167, AP: 0.7053
# Epoch 625
# Epoch: 625, AUC: 0.5167, AP: 0.7054
# Epoch 626
# Epoch: 626, AUC: 0.5160, AP: 0.7050
# Epoch 627
# Epoch: 627, AUC: 0.5135, AP: 0.7045
# Epoch 628
# Epoch: 628, AUC: 0.5107, AP: 0.7029
# Epoch 629
# Epoch: 629, AUC: 0.5089, AP: 0.7015
# Epoch 630
# Epoch: 630, AUC: 0.5095, AP: 0.7004
# Epoch 631
# Epoch: 631, AUC: 0.5107, AP: 0.7012
# Epoch 632
# Epoch: 632, AUC: 0.5132, AP: 0.7026
# Epoch 633
# Epoch: 633, AUC: 0.5136, AP: 0.7039
# Epoch 634
# Epoch: 634, AUC: 0.5163, AP: 0.7048
# Epoch 635
# Epoch: 635, AUC: 0.5160, AP: 0.7048
# Epoch 636
# Epoch: 636, AUC: 0.5151, AP: 0.7047
# Epoch 637
# Epoch: 637, AUC: 0.5151, AP: 0.7048
# Epoch 638
# Epoch: 638, AUC: 0.5149, AP: 0.7048
# Epoch 639
# Epoch: 639, AUC: 0.5153, AP: 0.7050
# Epoch 640
# Epoch: 640, AUC: 0.5140, AP: 0.7044
# Epoch 641
# Epoch: 641, AUC: 0.5126, AP: 0.7041
# Epoch 642
# Epoch: 642, AUC: 0.5122, AP: 0.7044
# Epoch 643
# Epoch: 643, AUC: 0.5146, AP: 0.7049
# Epoch 644
# Epoch: 644, AUC: 0.5148, AP: 0.7050
# Epoch 645
# Epoch: 645, AUC: 0.5153, AP: 0.7052
# Epoch 646
# Epoch: 646, AUC: 0.5149, AP: 0.7049
# Epoch 647
# Epoch: 647, AUC: 0.5141, AP: 0.7047
# Epoch 648
# Epoch: 648, AUC: 0.5137, AP: 0.7051
# Epoch 649
# Epoch: 649, AUC: 0.5144, AP: 0.7046
# Epoch 650
# Epoch: 650, AUC: 0.5137, AP: 0.7043
# Epoch 651
# Epoch: 651, AUC: 0.5141, AP: 0.7042
# Epoch 652
# Epoch: 652, AUC: 0.5140, AP: 0.7037
# Epoch 653
# Epoch: 653, AUC: 0.5147, AP: 0.7054
# Epoch 654
# Epoch: 654, AUC: 0.5136, AP: 0.7027
# Epoch 655
# Epoch: 655, AUC: 0.5144, AP: 0.7034
# Epoch 656
# Epoch: 656, AUC: 0.5152, AP: 0.7043
# Epoch 657
# Epoch: 657, AUC: 0.5154, AP: 0.7046
# Epoch 658
# Epoch: 658, AUC: 0.5152, AP: 0.7046
# Epoch 659
# Epoch: 659, AUC: 0.5146, AP: 0.7043
# Epoch 660
# Epoch: 660, AUC: 0.5140, AP: 0.7039
# Epoch 661
# Epoch: 661, AUC: 0.5119, AP: 0.7025
# Epoch 662
# Epoch: 662, AUC: 0.5108, AP: 0.7016
# Epoch 663
# Epoch: 663, AUC: 0.5110, AP: 0.7018
# Epoch 664
# Epoch: 664, AUC: 0.5131, AP: 0.7030
# Epoch 665
# Epoch: 665, AUC: 0.5139, AP: 0.7041
# Epoch 666
# Epoch: 666, AUC: 0.5153, AP: 0.7048
# Epoch 667
# Epoch: 667, AUC: 0.5162, AP: 0.7055
# Epoch 668
# Epoch: 668, AUC: 0.5167, AP: 0.7056
# Epoch 669
# Epoch: 669, AUC: 0.5173, AP: 0.7060
# Epoch 670
# Epoch: 670, AUC: 0.5167, AP: 0.7058
# Epoch 671
# Epoch: 671, AUC: 0.5146, AP: 0.7055
# Epoch 672
# Epoch: 672, AUC: 0.5123, AP: 0.7040
# Epoch 673
# Epoch: 673, AUC: 0.5119, AP: 0.7038
# Epoch 674
# Epoch: 674, AUC: 0.5112, AP: 0.7039
# Epoch 675
# Epoch: 675, AUC: 0.5123, AP: 0.7035
# Epoch 676
# Epoch: 676, AUC: 0.5130, AP: 0.7037
# Epoch 677
# Epoch: 677, AUC: 0.5144, AP: 0.7043
# Epoch 678
# Epoch: 678, AUC: 0.5155, AP: 0.7044
# Epoch 679
# Epoch: 679, AUC: 0.5153, AP: 0.7043
# Epoch 680
# Epoch: 680, AUC: 0.5133, AP: 0.7037
# Epoch 681
# Epoch: 681, AUC: 0.5124, AP: 0.7033
# Epoch 682
# Epoch: 682, AUC: 0.5117, AP: 0.7033
# Epoch 683
# Epoch: 683, AUC: 0.5121, AP: 0.7034
# Epoch 684
# Epoch: 684, AUC: 0.5120, AP: 0.7034
# Epoch 685
# Epoch: 685, AUC: 0.5127, AP: 0.7036
# Epoch 686
# Epoch: 686, AUC: 0.5143, AP: 0.7058
# Epoch 687
# Epoch: 687, AUC: 0.5147, AP: 0.7040
# Epoch 688
# Epoch: 688, AUC: 0.5150, AP: 0.7039
# Epoch 689
# Epoch: 689, AUC: 0.5153, AP: 0.7042
# Epoch 690
# Epoch: 690, AUC: 0.5149, AP: 0.7042
# Epoch 691
# Epoch: 691, AUC: 0.5138, AP: 0.7036
# Epoch 692
# Epoch: 692, AUC: 0.5127, AP: 0.7030
# Epoch 693
# Epoch: 693, AUC: 0.5122, AP: 0.7028
# Epoch 694
# Epoch: 694, AUC: 0.5129, AP: 0.7032
# Epoch 695
# Epoch: 695, AUC: 0.5134, AP: 0.7041
# Epoch 696
# Epoch: 696, AUC: 0.5137, AP: 0.7032
# Epoch 697
# Epoch: 697, AUC: 0.5126, AP: 0.7029
# Epoch 698
# Epoch: 698, AUC: 0.5130, AP: 0.7036
# Epoch 699
# Epoch: 699, AUC: 0.5123, AP: 0.7034
# Epoch 700
# Epoch: 700, AUC: 0.5119, AP: 0.7031
# Epoch 701
# Epoch: 701, AUC: 0.5119, AP: 0.7032
# Epoch 702
# Epoch: 702, AUC: 0.5118, AP: 0.7035
# Epoch 703
# Epoch: 703, AUC: 0.5134, AP: 0.7040
# Epoch 704
# Epoch: 704, AUC: 0.5159, AP: 0.7052
# Epoch 705
# Epoch: 705, AUC: 0.5166, AP: 0.7054
# Epoch 706
# Epoch: 706, AUC: 0.5155, AP: 0.7046
# Epoch 707
# Epoch: 707, AUC: 0.5116, AP: 0.7028
# Epoch 708
# Epoch: 708, AUC: 0.5108, AP: 0.7022
# Epoch 709
# Epoch: 709, AUC: 0.5107, AP: 0.7020
# Epoch 710
# Epoch: 710, AUC: 0.5108, AP: 0.7020
# Epoch 711
# Epoch: 711, AUC: 0.5113, AP: 0.7024
# Epoch 712
# Epoch: 712, AUC: 0.5139, AP: 0.7038
# Epoch 713
# Epoch: 713, AUC: 0.5159, AP: 0.7049
# Epoch 714
# Epoch: 714, AUC: 0.5190, AP: 0.7068
# Epoch 715
# Epoch: 715, AUC: 0.5194, AP: 0.7075
# Epoch 716
# Epoch: 716, AUC: 0.5184, AP: 0.7055
# Epoch 717
# Epoch: 717, AUC: 0.5149, AP: 0.7034
# Epoch 718
# Epoch: 718, AUC: 0.5101, AP: 0.7010
# Epoch 719
# Epoch: 719, AUC: 0.5081, AP: 0.7000
# Epoch 720
# Epoch: 720, AUC: 0.5098, AP: 0.7011
# Epoch 721
# Epoch: 721, AUC: 0.5101, AP: 0.7015
# Epoch 722
# Epoch: 722, AUC: 0.5126, AP: 0.7028
# Epoch 723
# Epoch: 723, AUC: 0.5146, AP: 0.7039
# Epoch 724
# Epoch: 724, AUC: 0.5159, AP: 0.7050
# Epoch 725
# Epoch: 725, AUC: 0.5165, AP: 0.7064
# Epoch 726
# Epoch: 726, AUC: 0.5161, AP: 0.7049
# Epoch 727
# Epoch: 727, AUC: 0.5154, AP: 0.7036
# Epoch 728
# Epoch: 728, AUC: 0.5131, AP: 0.7034
# Epoch 729
# Epoch: 729, AUC: 0.5115, AP: 0.7030
# Epoch 730
# Epoch: 730, AUC: 0.5111, AP: 0.7036
# Epoch 731
# Epoch: 731, AUC: 0.5124, AP: 0.7035
# Epoch 732
# Epoch: 732, AUC: 0.5128, AP: 0.7037
# Epoch 733
# Epoch: 733, AUC: 0.5164, AP: 0.7060
# Epoch 734
# Epoch: 734, AUC: 0.5165, AP: 0.7053
# Epoch 735
# Epoch: 735, AUC: 0.5162, AP: 0.7051
# Epoch 736
# Epoch: 736, AUC: 0.5133, AP: 0.7040
# Epoch 737
# Epoch: 737, AUC: 0.5122, AP: 0.7034
# Epoch 738
# Epoch: 738, AUC: 0.5112, AP: 0.7027
# Epoch 739
# Epoch: 739, AUC: 0.5114, AP: 0.7028
# Epoch 740
# Epoch: 740, AUC: 0.5108, AP: 0.7034
# Epoch 741
# Epoch: 741, AUC: 0.5127, AP: 0.7034
# Epoch 742
# Epoch: 742, AUC: 0.5143, AP: 0.7040
# Epoch 743
# Epoch: 743, AUC: 0.5141, AP: 0.7046
# Epoch 744
# Epoch: 744, AUC: 0.5140, AP: 0.7042
# Epoch 745
# Epoch: 745, AUC: 0.5129, AP: 0.7021
# Epoch 746
# Epoch: 746, AUC: 0.5115, AP: 0.7009
# Epoch 747
# Epoch: 747, AUC: 0.5118, AP: 0.7015
# Epoch 748
# Epoch: 748, AUC: 0.5137, AP: 0.7040
# Epoch 749
# Epoch: 749, AUC: 0.5137, AP: 0.7037
# Epoch 750
# Epoch: 750, AUC: 0.5146, AP: 0.7044
# Epoch 751
# Epoch: 751, AUC: 0.5151, AP: 0.7047
# Epoch 752
# Epoch: 752, AUC: 0.5154, AP: 0.7050
# Epoch 753
# Epoch: 753, AUC: 0.5147, AP: 0.7047
# Epoch 754
# Epoch: 754, AUC: 0.5138, AP: 0.7042
# Epoch 755
# Epoch: 755, AUC: 0.5134, AP: 0.7041
# Epoch 756
# Epoch: 756, AUC: 0.5129, AP: 0.7038
# Epoch 757
# Epoch: 757, AUC: 0.5127, AP: 0.7035
# Epoch 758
# Epoch: 758, AUC: 0.5127, AP: 0.7036
# Epoch 759
# Epoch: 759, AUC: 0.5140, AP: 0.7042
# Epoch 760
# Epoch: 760, AUC: 0.5145, AP: 0.7045
# Epoch 761
# Epoch: 761, AUC: 0.5139, AP: 0.7040
# Epoch 762
# Epoch: 762, AUC: 0.5130, AP: 0.7033
# Epoch 763
# Epoch: 763, AUC: 0.5114, AP: 0.7036
# Epoch 764
# Epoch: 764, AUC: 0.5094, AP: 0.7012
# Epoch 765
# Epoch: 765, AUC: 0.5093, AP: 0.7012
# Epoch 766
# Epoch: 766, AUC: 0.5093, AP: 0.7012
# Epoch 767
# Epoch: 767, AUC: 0.5094, AP: 0.7012
# Epoch 768
# Epoch: 768, AUC: 0.5104, AP: 0.7021
# Epoch 769
# Epoch: 769, AUC: 0.5120, AP: 0.7033
# Epoch 770
# Epoch: 770, AUC: 0.5146, AP: 0.7047
# Epoch 771
# Epoch: 771, AUC: 0.5157, AP: 0.7053
# Epoch 772
# Epoch: 772, AUC: 0.5147, AP: 0.7050
# Epoch 773
# Epoch: 773, AUC: 0.5123, AP: 0.7042
# Epoch 774
# Epoch: 774, AUC: 0.5125, AP: 0.7040
# Epoch 775
# Epoch: 775, AUC: 0.5127, AP: 0.7040
# Epoch 776
# Epoch: 776, AUC: 0.5123, AP: 0.7036
# Epoch 777
# Epoch: 777, AUC: 0.5126, AP: 0.7037
# Epoch 778
# Epoch: 778, AUC: 0.5146, AP: 0.7045
# Epoch 779
# Epoch: 779, AUC: 0.5155, AP: 0.7051
# Epoch 780
# Epoch: 780, AUC: 0.5149, AP: 0.7055
# Epoch 781
# Epoch: 781, AUC: 0.5149, AP: 0.7055
# Epoch 782
# Epoch: 782, AUC: 0.5149, AP: 0.7047
# Epoch 783
# Epoch: 783, AUC: 0.5139, AP: 0.7038
# Epoch 784
# Epoch: 784, AUC: 0.5112, AP: 0.7022
# Epoch 785
# Epoch: 785, AUC: 0.5098, AP: 0.7014
# Epoch 786
# Epoch: 786, AUC: 0.5103, AP: 0.7018
# Epoch 787
# Epoch: 787, AUC: 0.5109, AP: 0.7024
# Epoch 788
# Epoch: 788, AUC: 0.5119, AP: 0.7030
# Epoch 789
# Epoch: 789, AUC: 0.5143, AP: 0.7042
# Epoch 790
# Epoch: 790, AUC: 0.5163, AP: 0.7055
# Epoch 791
# Epoch: 791, AUC: 0.5183, AP: 0.7069
# Epoch 792
# Epoch: 792, AUC: 0.5162, AP: 0.7054
# Epoch 793
# Epoch: 793, AUC: 0.5135, AP: 0.7041
# Epoch 794
# Epoch: 794, AUC: 0.5121, AP: 0.7035
# Epoch 795
# Epoch: 795, AUC: 0.5125, AP: 0.7036
# Epoch 796
# Epoch: 796, AUC: 0.5122, AP: 0.7035
# Epoch 797
# Epoch: 797, AUC: 0.5118, AP: 0.7033
# Epoch 798
# Epoch: 798, AUC: 0.5125, AP: 0.7038
# Epoch 799
# Epoch: 799, AUC: 0.5125, AP: 0.7046
# Epoch 800
# Epoch: 800, AUC: 0.5139, AP: 0.7043
# Epoch 801
# Epoch: 801, AUC: 0.5127, AP: 0.7036
# Epoch 802
# Epoch: 802, AUC: 0.5119, AP: 0.7028
# Epoch 803
# Epoch: 803, AUC: 0.5109, AP: 0.7020
# Epoch 804
# Epoch: 804, AUC: 0.5105, AP: 0.7013
# Epoch 805
# Epoch: 805, AUC: 0.5101, AP: 0.7011
# Epoch 806
# Epoch: 806, AUC: 0.5096, AP: 0.7012
# Epoch 807
# Epoch: 807, AUC: 0.5107, AP: 0.7023
# Epoch 808
# Epoch: 808, AUC: 0.5109, AP: 0.7026
# Epoch 809
# Epoch: 809, AUC: 0.5109, AP: 0.7025
# Epoch 810
# Epoch: 810, AUC: 0.5110, AP: 0.7023
# Epoch 811
# Epoch: 811, AUC: 0.5126, AP: 0.7032
# Epoch 812
# Epoch: 812, AUC: 0.5121, AP: 0.7028
# Epoch 813
# Epoch: 813, AUC: 0.5115, AP: 0.7024
# Epoch 814
# Epoch: 814, AUC: 0.5096, AP: 0.7014
# Epoch 815
# Epoch: 815, AUC: 0.5085, AP: 0.7006
# Epoch 816
# Epoch: 816, AUC: 0.5102, AP: 0.7014
# Epoch 817
# Epoch: 817, AUC: 0.5096, AP: 0.7010
# Epoch 818
# Epoch: 818, AUC: 0.5099, AP: 0.7011
# Epoch 819
# Epoch: 819, AUC: 0.5099, AP: 0.7010
# Epoch 820
# Epoch: 820, AUC: 0.5092, AP: 0.7009
# Epoch 821
# Epoch: 821, AUC: 0.5122, AP: 0.7029
# Epoch 822
# Epoch: 822, AUC: 0.5136, AP: 0.7037
# Epoch 823
# Epoch: 823, AUC: 0.5165, AP: 0.7074
# Epoch 824
# Epoch: 824, AUC: 0.5154, AP: 0.7050
# Epoch 825
# Epoch: 825, AUC: 0.5135, AP: 0.7039
# Epoch 826
# Epoch: 826, AUC: 0.5101, AP: 0.7031
# Epoch 827
# Epoch: 827, AUC: 0.5110, AP: 0.7025
# Epoch 828
# Epoch: 828, AUC: 0.5106, AP: 0.7022
# Epoch 829
# Epoch: 829, AUC: 0.5117, AP: 0.7023
# Epoch 830
# Epoch: 830, AUC: 0.5124, AP: 0.7022
# Epoch 831
# Epoch: 831, AUC: 0.5145, AP: 0.7031
# Epoch 832
# Epoch: 832, AUC: 0.5162, AP: 0.7046
# Epoch 833
# Epoch: 833, AUC: 0.5142, AP: 0.7031
# Epoch 834
# Epoch: 834, AUC: 0.5125, AP: 0.7028
# Epoch 835
# Epoch: 835, AUC: 0.5104, AP: 0.7023
# Epoch 836
# Epoch: 836, AUC: 0.5107, AP: 0.7026
# Epoch 837
# Epoch: 837, AUC: 0.5111, AP: 0.7028
# Epoch 838
# Epoch: 838, AUC: 0.5118, AP: 0.7030
# Epoch 839
# Epoch: 839, AUC: 0.5125, AP: 0.7034
# Epoch 840
# Epoch: 840, AUC: 0.5130, AP: 0.7035
# Epoch 841
# Epoch: 841, AUC: 0.5142, AP: 0.7039
# Epoch 842
# Epoch: 842, AUC: 0.5145, AP: 0.7040
# Epoch 843
# Epoch: 843, AUC: 0.5151, AP: 0.7044
# Epoch 844
# Epoch: 844, AUC: 0.5146, AP: 0.7045
# Epoch 845
# Epoch: 845, AUC: 0.5122, AP: 0.7037
# Epoch 846
# Epoch: 846, AUC: 0.5116, AP: 0.7037
# Epoch 847
# Epoch: 847, AUC: 0.5125, AP: 0.7038
# Epoch 848
# Epoch: 848, AUC: 0.5123, AP: 0.7036
# Epoch 849
# Epoch: 849, AUC: 0.5119, AP: 0.7031
# Epoch 850
# Epoch: 850, AUC: 0.5105, AP: 0.7019
# Epoch 851
# Epoch: 851, AUC: 0.5112, AP: 0.7018
# Epoch 852
# Epoch: 852, AUC: 0.5120, AP: 0.7022
# Epoch 853
# Epoch: 853, AUC: 0.5122, AP: 0.7029
# Epoch 854
# Epoch: 854, AUC: 0.5116, AP: 0.7029
# Epoch 855
# Epoch: 855, AUC: 0.5132, AP: 0.7042
# Epoch 856
# Epoch: 856, AUC: 0.5144, AP: 0.7040
# Epoch 857
# Epoch: 857, AUC: 0.5092, AP: 0.7023
# Epoch 858
# Epoch: 858, AUC: 0.5098, AP: 0.7011
# Epoch 859
# Epoch: 859, AUC: 0.5101, AP: 0.7022
# Epoch 860
# Epoch: 860, AUC: 0.5098, AP: 0.7002
# Epoch 861
# Epoch: 861, AUC: 0.5103, AP: 0.7010
# Epoch 862
# Epoch: 862, AUC: 0.5108, AP: 0.7025
# Epoch 863
# Epoch: 863, AUC: 0.5122, AP: 0.7017
# Epoch 864
# Epoch: 864, AUC: 0.5118, AP: 0.7018
# Epoch 865
# Epoch: 865, AUC: 0.5110, AP: 0.7019
# Epoch 866
# Epoch: 866, AUC: 0.5100, AP: 0.7018
# Epoch 867
# Epoch: 867, AUC: 0.5110, AP: 0.7023
# Epoch 868
# Epoch: 868, AUC: 0.5131, AP: 0.7032
# Epoch 869
# Epoch: 869, AUC: 0.5124, AP: 0.7025
# Epoch 870
# Epoch: 870, AUC: 0.5117, AP: 0.7019
# Epoch 871
# Epoch: 871, AUC: 0.5119, AP: 0.7032
# Epoch 872
# Epoch: 872, AUC: 0.5113, AP: 0.7029
# Epoch 873
# Epoch: 873, AUC: 0.5116, AP: 0.7030
# Epoch 874
# Epoch: 874, AUC: 0.5118, AP: 0.7031
# Epoch 875
# Epoch: 875, AUC: 0.5115, AP: 0.7029
# Epoch 876
# Epoch: 876, AUC: 0.5117, AP: 0.7027
# Epoch 877
# Epoch: 877, AUC: 0.5116, AP: 0.7020
# Epoch 878
# Epoch: 878, AUC: 0.5119, AP: 0.7020
# Epoch 879
# Epoch: 879, AUC: 0.5122, AP: 0.7020
# Epoch 880
# Epoch: 880, AUC: 0.5123, AP: 0.7042
# Epoch 881
# Epoch: 881, AUC: 0.5122, AP: 0.7029
# Epoch 882
# Epoch: 882, AUC: 0.5106, AP: 0.7027
# Epoch 883
# Epoch: 883, AUC: 0.5102, AP: 0.7032
# Epoch 884
# Epoch: 884, AUC: 0.5116, AP: 0.7032
# Epoch 885
# Epoch: 885, AUC: 0.5138, AP: 0.7042
# Epoch 886
# Epoch: 886, AUC: 0.5156, AP: 0.7051
# Epoch 887
# Epoch: 887, AUC: 0.5153, AP: 0.7045
# Epoch 888
# Epoch: 888, AUC: 0.5143, AP: 0.7041
# Epoch 889
# Epoch: 889, AUC: 0.5121, AP: 0.7034
# Epoch 890
# Epoch: 890, AUC: 0.5112, AP: 0.7027
# Epoch 891
# Epoch: 891, AUC: 0.5113, AP: 0.7027
# Epoch 892
# Epoch: 892, AUC: 0.5109, AP: 0.7025
# Epoch 893
# Epoch: 893, AUC: 0.5115, AP: 0.7026
# Epoch 894
# Epoch: 894, AUC: 0.5132, AP: 0.7028
# Epoch 895
# Epoch: 895, AUC: 0.5126, AP: 0.7016
# Epoch 896
# Epoch: 896, AUC: 0.5127, AP: 0.7019
# Epoch 897
# Epoch: 897, AUC: 0.5124, AP: 0.7029
# Epoch 898
# Epoch: 898, AUC: 0.5109, AP: 0.7026
# Epoch 899
# Epoch: 899, AUC: 0.5119, AP: 0.7031
# Epoch 900
# Epoch: 900, AUC: 0.5121, AP: 0.7032
# Epoch 901
# Epoch: 901, AUC: 0.5117, AP: 0.7029
# Epoch 902
# Epoch: 902, AUC: 0.5115, AP: 0.7031
# Epoch 903
# Epoch: 903, AUC: 0.5128, AP: 0.7024
# Epoch 904
# Epoch: 904, AUC: 0.5158, AP: 0.7049
# Epoch 905
# Epoch: 905, AUC: 0.5156, AP: 0.7041
# Epoch 906
# Epoch: 906, AUC: 0.5144, AP: 0.7055
# Epoch 907
# Epoch: 907, AUC: 0.5108, AP: 0.7023
# Epoch 908
# Epoch: 908, AUC: 0.5106, AP: 0.7021
# Epoch 909
# Epoch: 909, AUC: 0.5106, AP: 0.7017
# Epoch 910
# Epoch: 910, AUC: 0.5097, AP: 0.7006
# Epoch 911
# Epoch: 911, AUC: 0.5068, AP: 0.6985
# Epoch 912
# Epoch: 912, AUC: 0.5101, AP: 0.7029
# Epoch 913
# Epoch: 913, AUC: 0.5113, AP: 0.7022
# Epoch 914
# Epoch: 914, AUC: 0.5133, AP: 0.7039
# Epoch 915
# Epoch: 915, AUC: 0.5167, AP: 0.7065
# Epoch 916
# Epoch: 916, AUC: 0.5169, AP: 0.7060
# Epoch 917
# Epoch: 917, AUC: 0.5153, AP: 0.7054
# Epoch 918
# Epoch: 918, AUC: 0.5134, AP: 0.7047
# Epoch 919
# Epoch: 919, AUC: 0.5133, AP: 0.7049
# Epoch 920
# Epoch: 920, AUC: 0.5139, AP: 0.7049
# Epoch 921
# Epoch: 921, AUC: 0.5139, AP: 0.7047
# Epoch 922
# Epoch: 922, AUC: 0.5132, AP: 0.7041
# Epoch 923
# Epoch: 923, AUC: 0.5120, AP: 0.7044
# Epoch 924
# Epoch: 924, AUC: 0.5123, AP: 0.7037
# Epoch 925
# Epoch: 925, AUC: 0.5138, AP: 0.7038
# Epoch 926
# Epoch: 926, AUC: 0.5124, AP: 0.7028
# Epoch 927
# Epoch: 927, AUC: 0.5087, AP: 0.7006
# Epoch 928
# Epoch: 928, AUC: 0.5069, AP: 0.6997
# Epoch 929
# Epoch: 929, AUC: 0.5065, AP: 0.7002
# Epoch 930
# Epoch: 930, AUC: 0.5101, AP: 0.7016
# Epoch 931
# Epoch: 931, AUC: 0.5103, AP: 0.7018
# Epoch 932
# Epoch: 932, AUC: 0.5109, AP: 0.7026
# Epoch 933
# Epoch: 933, AUC: 0.5126, AP: 0.7035
# Epoch 934
# Epoch: 934, AUC: 0.5144, AP: 0.7034
# Epoch 935
# Epoch: 935, AUC: 0.5143, AP: 0.7039
# Epoch 936
# Epoch: 936, AUC: 0.5126, AP: 0.7019
# Epoch 937
# Epoch: 937, AUC: 0.5135, AP: 0.7032
# Epoch 938
# Epoch: 938, AUC: 0.5122, AP: 0.7032
# Epoch 939
# Epoch: 939, AUC: 0.5128, AP: 0.7038
# Epoch 940
# Epoch: 940, AUC: 0.5128, AP: 0.7039
# Epoch 941
# Epoch: 941, AUC: 0.5123, AP: 0.7040
# Epoch 942
# Epoch: 942, AUC: 0.5131, AP: 0.7044
# Epoch 943
# Epoch: 943, AUC: 0.5151, AP: 0.7050
# Epoch 944
# Epoch: 944, AUC: 0.5142, AP: 0.7064
# Epoch 945
# Epoch: 945, AUC: 0.5118, AP: 0.7028
# Epoch 946
# Epoch: 946, AUC: 0.5109, AP: 0.7031
# Epoch 947
# Epoch: 947, AUC: 0.5126, AP: 0.7033
# Epoch 948
# Epoch: 948, AUC: 0.5125, AP: 0.7034
# Epoch 949
# Epoch: 949, AUC: 0.5131, AP: 0.7045
# Epoch 950
# Epoch: 950, AUC: 0.5122, AP: 0.7033
# Epoch 951
# Epoch: 951, AUC: 0.5114, AP: 0.7030
# Epoch 952
# Epoch: 952, AUC: 0.5126, AP: 0.7033
# Epoch 953
# Epoch: 953, AUC: 0.5146, AP: 0.7040
# Epoch 954
# Epoch: 954, AUC: 0.5156, AP: 0.7042
# Epoch 955
# Epoch: 955, AUC: 0.5143, AP: 0.7032
# Epoch 956
# Epoch: 956, AUC: 0.5129, AP: 0.7025
# Epoch 957
# Epoch: 957, AUC: 0.5121, AP: 0.7023
# Epoch 958
# Epoch: 958, AUC: 0.5119, AP: 0.7024
# Epoch 959
# Epoch: 959, AUC: 0.5126, AP: 0.7035
# Epoch 960
# Epoch: 960, AUC: 0.5116, AP: 0.7034
# Epoch 961
# Epoch: 961, AUC: 0.5123, AP: 0.7039
# Epoch 962
# Epoch: 962, AUC: 0.5136, AP: 0.7043
# Epoch 963
# Epoch: 963, AUC: 0.5132, AP: 0.7038
# Epoch 964
# Epoch: 964, AUC: 0.5126, AP: 0.7033
# Epoch 965
# Epoch: 965, AUC: 0.5132, AP: 0.7029
# Epoch 966
# Epoch: 966, AUC: 0.5131, AP: 0.7028
# Epoch 967
# Epoch: 967, AUC: 0.5132, AP: 0.7032
# Epoch 968
# Epoch: 968, AUC: 0.5115, AP: 0.7036
# Epoch 969
# Epoch: 969, AUC: 0.5123, AP: 0.7037
# Epoch 970
# Epoch: 970, AUC: 0.5119, AP: 0.7037
# Epoch 971
# Epoch: 971, AUC: 0.5124, AP: 0.7040
# Epoch 972
# Epoch: 972, AUC: 0.5138, AP: 0.7044
# Epoch 973
# Epoch: 973, AUC: 0.5138, AP: 0.7045
# Epoch 974
# Epoch: 974, AUC: 0.5141, AP: 0.7046
# Epoch 975
# Epoch: 975, AUC: 0.5145, AP: 0.7048
# Epoch 976
# Epoch: 976, AUC: 0.5142, AP: 0.7049
# Epoch 977
# Epoch: 977, AUC: 0.5136, AP: 0.7050
# Epoch 978
# Epoch: 978, AUC: 0.5133, AP: 0.7049
# Epoch 979
# Epoch: 979, AUC: 0.5131, AP: 0.7047
# Epoch 980
# Epoch: 980, AUC: 0.5121, AP: 0.7037
# Epoch 981
# Epoch: 981, AUC: 0.5132, AP: 0.7037
# Epoch 982
# Epoch: 982, AUC: 0.5110, AP: 0.7014
# Epoch 983
# Epoch: 983, AUC: 0.5122, AP: 0.7022
# Epoch 984
# Epoch: 984, AUC: 0.5136, AP: 0.7044
# Epoch 985
# Epoch: 985, AUC: 0.5161, AP: 0.7058
# Epoch 986
# Epoch: 986, AUC: 0.5211, AP: 0.7071
# Epoch 987
# Epoch: 987, AUC: 0.5152, AP: 0.7056
# Epoch 988
# Epoch: 988, AUC: 0.5132, AP: 0.7048
# Epoch 989
# Epoch: 989, AUC: 0.5134, AP: 0.7047
# Epoch 990
# Epoch: 990, AUC: 0.5146, AP: 0.7049
# Epoch 991
# Epoch: 991, AUC: 0.5141, AP: 0.7048
# Epoch 992
# Epoch: 992, AUC: 0.5133, AP: 0.7046
# Epoch 993
# Epoch: 993, AUC: 0.5128, AP: 0.7041
# Epoch 994
# Epoch: 994, AUC: 0.5128, AP: 0.7039
# Epoch 995
# Epoch: 995, AUC: 0.5129, AP: 0.7038
# Epoch 996
# Epoch: 996, AUC: 0.5122, AP: 0.7032
# Epoch 997
# Epoch: 997, AUC: 0.5118, AP: 0.7030
# Epoch 998
# Epoch: 998, AUC: 0.5117, AP: 0.7030
# Epoch 999
# Epoch: 999, AUC: 0.5140, AP: 0.7043
# Epoch 1000
# Epoch: 1000, AUC: 0.5156, AP: 0.7051

# %%
#RESET GRAPHS
graphs = {}
masks = {}
for incr in txs_dict.keys():
    graphs[incr], masks[incr] = make_subgraph(txs_dict[incr], feats)

# %%
#Stitch embeddings and feats into main tensor

# %%
# # model.eval()
# dev = torch.device('cuda:0')
# f = model.encode(graphs['2/14'].x.to(dev), graphs['2/13'].edge_index.to(dev))

# %%
len(nodes)
# Out:
# 274173
